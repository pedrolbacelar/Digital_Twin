# %%
from dtwinpylib.dtwinpy.Digital_Twin import Digital_Twin
mydt = Digital_Twin(name= "5s_determ_old")
mydt.run_digital_model(verbose= True, plot= True, targeted_part_id= 1)
# Out:
# Deleting existing model (excepted by 'initial.json') from the relative folder path:'models/5s_determ_old'
# Done! Deleted 0 successfuly
# --- printing databases paths ---
# Digital Database: 'databases/5s_determ_old/digital_database.db'
# Real Database: 'databases/5s_determ_old/real_database.db'
# ID Database: 'databases/5s_determ_old/ID_database.db'
# 20 March 14:41:27 |---- Digital Twin '5s_determ_old' created sucessfully ----
# ==========  Reading the Model: 5s_determ_old  ==========
# ===> Big Picture
# Total number of Machines: 5
# Total number of Queues: 5
#
# ===>Detailed view of Queues:
# ----------------
# Queue 1
# Arc links: [5, 1]
# Capacity: 10
# |-- Parts stored: Part 1
# |-- Parts stored: Part 2
# |-- Parts stored: Part 3
# |-- Parts stored: Part 4
# |-- Parts stored: Part 5
# |-- Parts stored: Part 6
# |-- Parts stored: Part 7
# Queue Lenght: 7
# ----------------
# Queue 2
# Arc links: [1, 2]
# Capacity: 10
# Queue Lenght: 0
# ----------------
# Queue 3
# ...
