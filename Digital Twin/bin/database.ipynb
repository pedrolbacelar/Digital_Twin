# %% [markdown]
# # Working with Database
# In this notebook we're going to extract from the database some information from every part and from every machine

# %% [markdown]
# Importing libraries

# %%
from dtwinpylib.dtwinpy.Digital_Twin import Digital_Twin

import importlib
import dtwinpylib
importlib.reload(dtwinpylib.dtwinpy.Digital_Twin) #reload this specifc module to upadte the class
# Out:
# <module 'dtwinpylib.dtwinpy.Digital_Twin' from 'c:\\Users\\pedro\\Github Repositories\\Digital_Twin\\Digital Twin\\dtwinpylib\\dtwinpy\\Digital_Twin.py'>

# %% [markdown]
# First, let's create some data from a simulation

# %%
database_path = "databases/model_5s_testing_db.db"
digital_twin = Digital_Twin(name= "model_5stations_closed",
    model_path= "models/model_5s_closed_no_shadow.json",
    database_path= database_path,
    initial=True, maxparts=10)

# %%
database_path = "databases/model_5s_testing_db.db"
digital_twin = Digital_Twin(name= "model_5s_closed_no_shadow",
    initial=True, maxparts=10)

# %% [markdown]
# Run the simulation for 10 parts

# %%
digital_twin.run_digital_model()
# Out:
# ==========  Reading the Model: model_5s_closed_no_shadow  ==========
# ===> Big Picture
# Total number of Machines: 5
# Total number of Queues: 6
#
# ===>Detailed view of Queues:
# ----------------
# Queue 1
# Arc links: [1, 2]
# Capacity: 1
# Queue Lenght: 0
# ----------------
# Queue 2
# Arc links: [1, 3]
# Capacity: 10
# Queue Lenght: 0
# ----------------
# Queue 3
# Arc links: [2, 4]
# Capacity: 10
# Queue Lenght: 0
# ----------------
# Queue 4
# Arc links: [3, 4]
# Capacity: 10
# Queue Lenght: 0
# ----------------
# Queue 5
# Arc links: [4, 5]
# Capacity: 10
# Queue Lenght: 0
# ----------------
# Queue 6
# Arc links: [5, 1]
# Capacity: 10
# Parts stored: Part 1
# Part Processes for Trace Driven Simulation: None
# Parts stored: Part 2
# Part Processes for Trace Driven Simulation: None
# Parts stored: Part 3
# Part Processes for Trace Driven Simulation: None
# Queue Lenght: 3
#
# ===>Detailed view of Machines:
# ----------------
# > Machine 1
# --Queue In:--
# Queue 6
# --Queue Out:--
# Queue 1
# Queue 2
# ---Process Time for quasi Trace Driven Simulation---
# None
# ----------------
# > Machine 2
# --Queue In:--
# Queue 1
# --Queue Out:--
# Queue 3
# ---Process Time for quasi Trace Driven Simulation---
# None
# ----------------
# > Machine 3
# --Queue In:--
# Queue 2
# --Queue Out:--
# Queue 4
# ---Process Time for quasi Trace Driven Simulation---
# None
# ----------------
# > Machine 4
# --Queue In:--
# Queue 3
# Queue 4
# --Queue Out:--
# Queue 5
# ---Process Time for quasi Trace Driven Simulation---
# None
# ----------------
# > Machine 5
# --Queue In:--
# Queue 5
# --Queue Out:--
# Queue 6
# ---Process Time for quasi Trace Driven Simulation---
# None
# ### ============ Simulation Started ============ ###
# === Reading all the events from table: digital_log ===
# (1, 0, 'Machine 1', 'Started', 'Part 1', 'Queue 6')
# (2, 5000, 'Machine 1', 'Finished', 'Part 1', 'Queue 1')
# (3, 5000, 'Machine 1', 'Started', 'Part 2', 'Queue 6')
# (4, 5000, 'Machine 2', 'Started', 'Part 1', 'Queue 1')
# (5, 10000, 'Machine 1', 'Finished', 'Part 2', 'Queue 1')
# (6, 10000, 'Machine 1', 'Started', 'Part 3', 'Queue 6')
# (7, 15000, 'Machine 1', 'Finished', 'Part 3', 'Queue 2')
# (8, 15000, 'Machine 3', 'Started', 'Part 3', 'Queue 2')
# (9, 20000, 'Machine 2', 'Finished', 'Part 1', 'Queue 3')
# (10, 20000, 'Machine 2', 'Started', 'Part 2', 'Queue 1')
# (11, 20000, 'Machine 4', 'Started', 'Part 1', 'Queue 3')
# (12, 25000, 'Machine 4', 'Finished', 'Part 1', 'Queue 5')
# (13, 25000, 'Machine 5', 'Started', 'Part 1', 'Queue 5')
# (14, 30000, 'Machine 3', 'Finished', 'Part 3', 'Queue 4')
# (15, 30000, 'Machine 4', 'Started', 'Part 3', 'Queue 4')
# (16, 35000, 'Machine 2', 'Finished', 'Part 2', 'Queue 3')
# (17, 35000, 'Machine 5', 'Finished', 'Part 1', 'Queue 6')
# (18, 35000, 'Machine 4', 'Finished', 'Part 3', 'Queue 5')
# (19, 35000, 'Machine 4', 'Started', 'Part 2', 'Queue 3')
# (20, 35000, 'Machine 1', 'Started', 'Part 4', 'Queue 6')
# (21, 35001, 'Machine 5', 'Started', 'Part 3', 'Queue 5')
# (22, 40000, 'Machine 4', 'Finished', 'Part 2', 'Queue 5')
# (23, 40000, 'Machine 1', 'Finished', 'Part 4', 'Queue 1')
# (24, 40000, 'Machine 2', 'Started', 'Part 4', 'Queue 1')
# (25, 45001, 'Machine 5', 'Finished', 'Part 3', 'Queue 6')
# (26, 45001, 'Machine 5', 'Started', 'Part 2', 'Queue 5')
# (27, 45001, 'Machine 1', 'Started', 'Part 5', 'Queue 6')
# (28, 50001, 'Machine 1', 'Finished', 'Part 5', 'Queue 1')
# (29, 55000, 'Machine 2', 'Finished', 'Part 4', 'Queue 3')
# (30, 55000, 'Machine 2', 'Started', 'Part 5', 'Queue 1')
# (31, 55000, 'Machine 4', 'Started', 'Part 4', 'Queue 3')
# (32, 55001, 'Machine 5', 'Finished', 'Part 2', 'Queue 6')
# (33, 55001, 'Machine 1', 'Started', 'Part 6', 'Queue 6')
# (34, 60000, 'Machine 4', 'Finished', 'Part 4', 'Queue 5')
# (35, 60000, 'Machine 5', 'Started', 'Part 4', 'Queue 5')
# (36, 60001, 'Machine 1', 'Finished', 'Part 6', 'Queue 1')
# (37, 70000, 'Machine 2', 'Finished', 'Part 5', 'Queue 3')
# (38, 70000, 'Machine 2', 'Started', 'Part 6', 'Queue 1')
# (39, 70000, 'Machine 5', 'Finished', 'Part 4', 'Queue 6')
# (40, 70000, 'Machine 1', 'Started', 'Part 7', 'Queue 6')
# (41, 70000, 'Machine 4', 'Started', 'Part 5', 'Queue 3')
# (42, 75000, 'Machine 1', 'Finished', 'Part 7', 'Queue 1')
# (43, 75000, 'Machine 4', 'Finished', 'Part 5', 'Queue 5')
# (44, 75000, 'Machine 5', 'Started', 'Part 5', 'Queue 5')
# (45, 85000, 'Machine 2', 'Finished', 'Part 6', 'Queue 3')
# (46, 85000, 'Machine 2', 'Started', 'Part 7', 'Queue 1')
# (47, 85000, 'Machine 5', 'Finished', 'Part 5', 'Queue 6')
# (48, 85000, 'Machine 1', 'Started', 'Part 8', 'Queue 6')
# (49, 85000, 'Machine 4', 'Started', 'Part 6', 'Queue 3')
# (50, 90000, 'Machine 1', 'Finished', 'Part 8', 'Queue 1')
# (51, 90000, 'Machine 4', 'Finished', 'Part 6', 'Queue 5')
# (52, 90000, 'Machine 5', 'Started', 'Part 6', 'Queue 5')
# (53, 100000, 'Machine 2', 'Finished', 'Part 7', 'Queue 3')
# (54, 100000, 'Machine 2', 'Started', 'Part 8', 'Queue 1')
# (55, 100000, 'Machine 5', 'Finished', 'Part 6', 'Queue 6')
# (56, 100000, 'Machine 1', 'Started', 'Part 9', 'Queue 6')
# (57, 100000, 'Machine 4', 'Started', 'Part 7', 'Queue 3')
# (58, 105000, 'Machine 1', 'Finished', 'Part 9', 'Queue 1')
# (59, 105000, 'Machine 4', 'Finished', 'Part 7', 'Queue 5')
# (60, 105000, 'Machine 5', 'Started', 'Part 7', 'Queue 5')
# (61, 115000, 'Machine 2', 'Finished', 'Part 8', 'Queue 3')
# (62, 115000, 'Machine 2', 'Started', 'Part 9', 'Queue 1')
# (63, 115000, 'Machine 5', 'Finished', 'Part 7', 'Queue 6')
# (64, 115000, 'Machine 1', 'Started', 'Part 10', 'Queue 6')
# (65, 115000, 'Machine 4', 'Started', 'Part 8', 'Queue 3')
# (66, 120000, 'Machine 1', 'Finished', 'Part 10', 'Queue 1')
# (67, 120000, 'Machine 4', 'Finished', 'Part 8', 'Queue 5')
# (68, 120000, 'Machine 5', 'Started', 'Part 8', 'Queue 5')
# (69, 130000, 'Machine 2', 'Finished', 'Part 9', 'Queue 3')
# (70, 130000, 'Machine 2', 'Started', 'Part 10', 'Queue 1')
# (71, 130000, 'Machine 5', 'Finished', 'Part 8', 'Queue 6')
# (72, 130000, 'Machine 1', 'Started', 'Part 11', 'Queue 6')
# (73, 130000, 'Machine 4', 'Started', 'Part 9', 'Queue 3')
# (74, 135000, 'Machine 1', 'Finished', 'Part 11', 'Queue 1')
# (75, 135000, 'Machine 4', 'Finished', 'Part 9', 'Queue 5')
# (76, 135000, 'Machine 5', 'Started', 'Part 9', 'Queue 5')
# (77, 145000, 'Machine 2', 'Finished', 'Part 10', 'Queue 3')
# (78, 145000, 'Machine 2', 'Started', 'Part 11', 'Queue 1')
# (79, 145000, 'Machine 5', 'Finished', 'Part 9', 'Queue 6')
# (80, 145000, 'Machine 1', 'Started', 'Part 12', 'Queue 6')
# (81, 145000, 'Machine 4', 'Started', 'Part 10', 'Queue 3')
# (82, 150000, 'Machine 1', 'Finished', 'Part 12', 'Queue 1')
# (83, 150000, 'Machine 4', 'Finished', 'Part 10', 'Queue 5')
# (84, 150000, 'Machine 5', 'Started', 'Part 10', 'Queue 5')
# (85, 160000, 'Machine 2', 'Finished', 'Part 11', 'Queue 3')
# (86, 160000, 'Machine 2', 'Started', 'Part 12', 'Queue 1')
# (87, 160000, 'Machine 5', 'Finished', 'Part 10', 'Queue 6')
# (88, 160000, 'Machine 1', 'Started', 'Part 13', 'Queue 6')
# (89, 160000, 'Machine 4', 'Started', 'Part 11', 'Queue 3')
# ### ============ Simulation Done ============ ###
# ================ Running Analysis ================
# Number of Parts finished: 10
# Total time of Simulation: 160000
# - Maximum Cycle Time: 55001
# - Minimum Cycle Time: 35000
# >>> Average system cycle time: 43500.0 [time unit]***
# >>> System Throughput: 6.25e-05 [parts / time unit]

# %% [markdown]
# Connect to the database

# %%
import sqlite3

conn = sqlite3.connect(database_path)
c = conn.cursor()

# %% [markdown]
# Execute an SQL query to select the unique Part IDs from the table:

# %%
part_ids = c.execute("SELECT DISTINCT part_id FROM digital_log").fetchall()
part_ids
# Out:
# [('Part 1',),
#  ('Part 2',),
#  ('Part 3',),
#  ('Part 4',),
#  ('Part 5',),
#  ('Part 6',),
#  ('Part 7',),
#  ('Part 8',),
#  ('Part 9',),
#  ('Part 10',),
#  ('Part 11',),
#  ('Part 12',),
#  ('Part 13',)]

# %% [markdown]
# For each Part ID, execute another SQL query to select the timestemp and status columns:

# %%
part_ids[0]
# Out:
# ('Part 1',)

# %%
part_id = part_ids[0][0]
results = c.execute("SELECT timestamp, activity_type FROM digital_log WHERE part_id=?", part_ids[0]).fetchall()
results
# Out:
# [(0, 'Started'),
#  (5000, 'Finished'),
#  (5000, 'Started'),
#  (20000, 'Finished'),
#  (20000, 'Started'),
#  (25000, 'Finished'),
#  (25000, 'Started'),
#  (35000, 'Finished')]

# %% [markdown]
# Example of the TDS dictionary
# matrix_TDS = {
#
#     "Part 1":[P1, P2, ..., Pn],
#
#     "Part 2":[P1, P2, ..., Pm]
#
# }

# %%
simtype = "TDS"
simtype = "qTDS"

conn = sqlite3.connect(database_path)
c = conn.cursor()

#--- TDS
part_ids = c.execute("SELECT DISTINCT part_id FROM digital_log").fetchall()
matrix_ptime_TDS = []
part_matrix_full_trace = []



for part_id in part_ids:
    part_full_trace = c.execute("SELECT timestamp, activity_type FROM digital_log WHERE part_id=?", part_id).fetchall()
    part_matrix_full_trace.append(part_full_trace)


    started_time = None
    finished_time = None
    processed_time = None
    part_trace = []

    for event in part_full_trace:
        #--- Extract the Started and Finished time
        if event[1] == 'Started':
            started_time = event[0]
        elif event[1] == 'Finished':
            finished_time = event[0]
        
        #--- Calculate the process time
        if started_time != None and finished_time != None:
            processed_time = finished_time - started_time

            #--- Add event process time to the part trace
            part_trace.append(processed_time)

            #--- reset local started and finished time for the next cycle
            started_time = None
            finished_time = None
            processed_time = None
    
    #--- Add part trace to the matrix of all parts traces
    matrix_ptime_TDS.append(part_trace)
    
matrix_ptime_TDS
# Out:
# [[5000, 15000, 5000, 10000],
#  [5000, 15000, 5000, 10000],
#  [5000, 15000, 5000, 10000],
#  [5000, 15000, 5000, 10000],
#  [5000, 15000, 5000, 10000],
#  [5000, 15000, 5000, 10000],
#  [5000, 15000, 5000, 10000],
#  [5000, 15000, 5000, 10000],
#  [5000, 15000, 5000, 10000],
#  [5000, 15000, 5000, 10000],
#  [5000, 15000],
#  [5000],
#  []]

# %%
part_ids
# Out:
# [('Part 1',),
#  ('Part 2',),
#  ('Part 3',),
#  ('Part 4',),
#  ('Part 5',),
#  ('Part 6',),
#  ('Part 7',),
#  ('Part 8',),
#  ('Part 9',),
#  ('Part 10',),
#  ('Part 11',),
#  ('Part 12',),
#  ('Part 13',)]

# %%
part_matrix_full_trace
# Out:
# [[(0, 'Started'),
#   (5000, 'Finished'),
#   (5000, 'Started'),
#   (20000, 'Finished'),
#   (20000, 'Started'),
#   (25000, 'Finished'),
#   (25000, 'Started'),
#   (35000, 'Finished')],
#  [(5000, 'Started'),
#   (10000, 'Finished'),
#   (20000, 'Started'),
#   (35000, 'Finished'),
#   (35000, 'Started'),
#   (40000, 'Finished'),
#   (45001, 'Started'),
#   (55001, 'Finished')],
#  [(10000, 'Started'),
#   (15000, 'Finished'),
#   (15000, 'Started'),
#   (30000, 'Finished'),
#   (30000, 'Started'),
#   (35000, 'Finished'),
#   (35001, 'Started'),
#   (45001, 'Finished')],
#  [(35000, 'Started'),
#   (40000, 'Finished'),
#   (40000, 'Started'),
#   (55000, 'Finished'),
#   (55000, 'Started'),
#   (60000, 'Finished'),
#   (60000, 'Started'),
#   (70000, 'Finished')],
#  [(45001, 'Started'),
#   (50001, 'Finished'),
#   (55000, 'Started'),
#   (70000, 'Finished'),
#   (70000, 'Started'),
#   (75000, 'Finished'),
#   (75000, 'Started'),
#   (85000, 'Finished')],
#  [(55001, 'Started'),
#   (60001, 'Finished'),
#   (70000, 'Started'),
#   (85000, 'Finished'),
#   (85000, 'Started'),
#   (90000, 'Finished'),
#   (90000, 'Started'),
#   (100000, 'Finished')],
#  [(70000, 'Started'),
#   (75000, 'Finished'),
#   (85000, 'Started'),
#   (100000, 'Finished'),
#   (100000, 'Started'),
#   (105000, 'Finished'),
#   (105000, 'Started'),
#   (115000, 'Finished')],
#  [(85000, 'Started'),
#   (90000, 'Finished'),
#   (100000, 'Started'),
#   (115000, 'Finished'),
#   (115000, 'Started'),
#   (120000, 'Finished'),
#   (120000, 'Started'),
#   (130000, 'Finished')],
#  [(100000, 'Started'),
#   (105000, 'Finished'),
#   (115000, 'Started'),
#   (130000, 'Finished'),
#   (130000, 'Started'),
#   (135000, 'Finished'),
#   (135000, 'Started'),
#   (145000, 'Finished')],
#  [(115000, 'Started'),
#   (120000, 'Finished'),
#   (130000, 'Started'),
#   (145000, 'Finished'),
#   (145000, 'Started'),
#   (150000, 'Finished'),
#   (150000, 'Started'),
#   (160000, 'Finished')],
#  [(130000, 'Started'),
#   (135000, 'Finished'),
#   (145000, 'Started'),
#   (160000, 'Finished'),
#   (160000, 'Started')],
#  [(145000, 'Started'), (150000, 'Finished'), (160000, 'Started')],
#  [(160000, 'Started')]]

# %% [markdown]
# ### Generation of trace for qTDS

# %%
conn = sqlite3.connect(database_path)
c = conn.cursor()
#--- qTDS
machines_ids = c.execute("SELECT DISTINCT machine_id FROM digital_log").fetchall()
matrix_ptime_qTDS = []
machine_matrix_full_trace = []


for machine_id in machines_ids:
    machine_full_trace = c.execute("SELECT timestamp, activity_type FROM digital_log WHERE machine_id=?", machine_id).fetchall()
    machine_matrix_full_trace.append(machine_full_trace)


    started_time = None
    finished_time = None
    processed_time = None
    machine_trace = []

    for event in machine_full_trace:
        #--- Extract the Started and Finished time
        if event[1] == 'Started':
            started_time = event[0]
        elif event[1] == 'Finished':
            finished_time = event[0]
        
        #--- Calculate the process time
        if started_time != None and finished_time != None:
            processed_time = finished_time - started_time

            #--- Add event process time to the part trace
            machine_trace.append(processed_time)

            #--- reset local started and finished time for the next cycle
            started_time = None
            finished_time = None
            processed_time = None
    
    #--- Add part trace to the matrix of all parts traces
    matrix_ptime_qTDS.append(machine_trace)
    
matrix_ptime_qTDS
# Out:
# [[5000, 5000, 5000, 5000, 5000, 5000, 5000, 5000, 5000, 5000, 5000, 5000],
#  [15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000],
#  [15000],
#  [5000, 5000, 5000, 5000, 5000, 5000, 5000, 5000, 5000, 5000],
#  [10000, 10000, 10000, 10000, 10000, 10000, 10000, 10000, 10000, 10000]]

# %%
machines_ids
# Out:
# [('Machine 1',),
#  ('Machine 2',),
#  ('Machine 3',),
#  ('Machine 4',),
#  ('Machine 5',)]

# %% [markdown]
# ## Output Event Trace Generation
# Here we test how to generate the traces for the event output (Ys) that will be used in LCSS

# %% [markdown]
# Select every event from the table in sequence as tuples

# %%
import sqlite3
database_path = "databases/digital_model_5s_closed_no_shadow_real_db.db"
with sqlite3.connect(database_path) as digital_model_DB: 
    events_full_trace = digital_model_DB.execute("SELECT timestamp, machine_id, activity_type, part_id FROM digital_log").fetchall()
events_full_trace
# Out:
# [(0, 'Machine 1', 'Started', 'Part 1'),
#  (5000, 'Machine 1', 'Finished', 'Part 1'),
#  (5000, 'Machine 1', 'Started', 'Part 2'),
#  (5000, 'Machine 2', 'Started', 'Part 1'),
#  (10000, 'Machine 1', 'Finished', 'Part 2'),
#  (10000, 'Machine 1', 'Started', 'Part 3'),
#  (15000, 'Machine 1', 'Finished', 'Part 3'),
#  (15000, 'Machine 1', 'Started', 'Part 4'),
#  (15000, 'Machine 3', 'Started', 'Part 3'),
#  (20000, 'Machine 2', 'Finished', 'Part 1'),
#  (20000, 'Machine 2', 'Started', 'Part 2'),
#  (20000, 'Machine 1', 'Finished', 'Part 4'),
#  (20000, 'Machine 1', 'Started', 'Part 5'),
#  (20000, 'Machine 4', 'Started', 'Part 1'),
#  (25000, 'Machine 1', 'Finished', 'Part 5'),
#  (25000, 'Machine 1', 'Started', 'Part 6'),
#  (25000, 'Machine 4', 'Finished', 'Part 1'),
#  (25000, 'Machine 5', 'Started', 'Part 1'),
#  (30000, 'Machine 3', 'Finished', 'Part 3'),
#  (30000, 'Machine 3', 'Started', 'Part 5'),
#  (30000, 'Machine 1', 'Finished', 'Part 6'),
#  (30000, 'Machine 1', 'Started', 'Part 7'),
#  (30000, 'Machine 4', 'Started', 'Part 3'),
#  (35000, 'Machine 2', 'Finished', 'Part 2'),
#  (35000, 'Machine 2', 'Started', 'Part 4'),
#  (35000, 'Machine 5', 'Finished', 'Part 1'),
#  (35000, 'Machine 1', 'Finished', 'Part 7'),
#  (35000, 'Machine 1', 'Started', 'Part 8'),
#  (35000, 'Machine 4', 'Finished', 'Part 3'),
#  (35000, 'Machine 4', 'Started', 'Part 2'),
#  (35001, 'Machine 5', 'Started', 'Part 3'),
#  (40000, 'Machine 1', 'Finished', 'Part 8'),
#  (40000, 'Machine 1', 'Started', 'Part 9'),
#  (40000, 'Machine 4', 'Finished', 'Part 2'),
#  (45000, 'Machine 3', 'Finished', 'Part 5'),
#  (45000, 'Machine 3', 'Started', 'Part 6'),
#  (45000, 'Machine 1', 'Finished', 'Part 9'),
#  (45000, 'Machine 1', 'Started', 'Part 10'),
#  (45000, 'Machine 4', 'Started', 'Part 5'),
#  (45001, 'Machine 5', 'Finished', 'Part 3'),
#  (45001, 'Machine 5', 'Started', 'Part 2'),
#  (50000, 'Machine 2', 'Finished', 'Part 4'),
#  (50000, 'Machine 2', 'Started', 'Part 7'),
#  (50000, 'Machine 1', 'Finished', 'Part 10'),
#  (50000, 'Machine 1', 'Started', 'Part 11'),
#  (50000, 'Machine 4', 'Finished', 'Part 5'),
#  (50000, 'Machine 4', 'Started', 'Part 4'),
#  (55000, 'Machine 1', 'Finished', 'Part 11'),
#  (55000, 'Machine 1', 'Started', 'Part 12'),
#  (55000, 'Machine 4', 'Finished', 'Part 4'),
#  (55001, 'Machine 5', 'Finished', 'Part 2'),
#  (55001, 'Machine 5', 'Started', 'Part 5'),
#  (60000, 'Machine 3', 'Finished', 'Part 6'),
#  (60000, 'Machine 3', 'Started', 'Part 8'),
#  (60000, 'Machine 1', 'Finished', 'Part 12'),
#  (60000, 'Machine 1', 'Started', 'Part 13'),
#  (60000, 'Machine 4', 'Started', 'Part 6'),
#  (65000, 'Machine 2', 'Finished', 'Part 7'),
#  (65000, 'Machine 2', 'Started', 'Part 10'),
#  (65000, 'Machine 1', 'Finished', 'Part 13'),
#  (65000, 'Machine 4', 'Finished', 'Part 6'),
#  (65000, 'Machine 4', 'Started', 'Part 7'),
#  (65001, 'Machine 5', 'Finished', 'Part 5'),
#  (65001, 'Machine 5', 'Started', 'Part 4'),
#  (65001, 'Machine 1', 'Started', 'Part 14'),
#  (70000, 'Machine 4', 'Finished', 'Part 7'),
#  (70001, 'Machine 1', 'Finished', 'Part 14'),
#  (75000, 'Machine 3', 'Finished', 'Part 8'),
#  (75000, 'Machine 3', 'Started', 'Part 9'),
#  (75000, 'Machine 4', 'Started', 'Part 8'),
#  (75001, 'Machine 5', 'Finished', 'Part 4'),
#  (75001, 'Machine 5', 'Started', 'Part 6'),
#  (75001, 'Machine 1', 'Started', 'Part 15'),
#  (80000, 'Machine 2', 'Finished', 'Part 10'),
#  (80000, 'Machine 2', 'Started', 'Part 13'),
#  (80000, 'Machine 4', 'Finished', 'Part 8'),
#  (80000, 'Machine 4', 'Started', 'Part 10'),
#  (80001, 'Machine 1', 'Finished', 'Part 15'),
#  (85000, 'Machine 4', 'Finished', 'Part 10'),
#  (85001, 'Machine 5', 'Finished', 'Part 6'),
#  (85001, 'Machine 5', 'Started', 'Part 7'),
#  (85001, 'Machine 1', 'Started', 'Part 16'),
#  (90000, 'Machine 3', 'Finished', 'Part 9'),
#  (90000, 'Machine 3', 'Started', 'Part 11'),
#  (90000, 'Machine 4', 'Started', 'Part 9'),
#  (90001, 'Machine 1', 'Finished', 'Part 16'),
#  (95000, 'Machine 2', 'Finished', 'Part 13'),
#  (95000, 'Machine 2', 'Started', 'Part 15'),
#  (95000, 'Machine 4', 'Finished', 'Part 9'),
#  (95000, 'Machine 4', 'Started', 'Part 13'),
#  (95001, 'Machine 5', 'Finished', 'Part 7'),
#  (95001, 'Machine 5', 'Started', 'Part 8'),
#  (95001, 'Machine 1', 'Started', 'Part 17'),
#  (100000, 'Machine 4', 'Finished', 'Part 13'),
#  (100001, 'Machine 1', 'Finished', 'Part 17'),
#  (105000, 'Machine 3', 'Finished', 'Part 11'),
#  (105000, 'Machine 3', 'Started', 'Part 12'),
#  (105000, 'Machine 4', 'Started', 'Part 11'),
#  (105001, 'Machine 5', 'Finished', 'Part 8'),
#  (105001, 'Machine 5', 'Started', 'Part 10'),
#  (105001, 'Machine 1', 'Started', 'Part 18'),
#  (110000, 'Machine 2', 'Finished', 'Part 15'),
#  (110000, 'Machine 2', 'Started', 'Part 17'),
#  (110000, 'Machine 4', 'Finished', 'Part 11'),
#  (110000, 'Machine 4', 'Started', 'Part 15'),
#  (110001, 'Machine 1', 'Finished', 'Part 18'),
#  (115000, 'Machine 4', 'Finished', 'Part 15'),
#  (115001, 'Machine 5', 'Finished', 'Part 10'),
#  (115001, 'Machine 5', 'Started', 'Part 9'),
#  (115001, 'Machine 1', 'Started', 'Part 19'),
#  (120000, 'Machine 3', 'Finished', 'Part 12'),
#  (120000, 'Machine 3', 'Started', 'Part 14'),
#  (120000, 'Machine 4', 'Started', 'Part 12'),
#  (120001, 'Machine 1', 'Finished', 'Part 19'),
#  (125000, 'Machine 2', 'Finished', 'Part 17'),
#  (125000, 'Machine 2', 'Started', 'Part 18'),
#  (125000, 'Machine 4', 'Finished', 'Part 12'),
#  (125000, 'Machine 4', 'Started', 'Part 17'),
#  (125001, 'Machine 5', 'Finished', 'Part 9'),
#  (125001, 'Machine 5', 'Started', 'Part 13'),
#  (125001, 'Machine 1', 'Started', 'Part 20'),
#  (130000, 'Machine 4', 'Finished', 'Part 17'),
#  (130001, 'Machine 1', 'Finished', 'Part 20'),
#  (135000, 'Machine 3', 'Finished', 'Part 14'),
#  (135000, 'Machine 3', 'Started', 'Part 16'),
#  (135000, 'Machine 4', 'Started', 'Part 14'),
#  (135001, 'Machine 5', 'Finished', 'Part 13'),
#  (135001, 'Machine 5', 'Started', 'Part 11'),
#  (135001, 'Machine 1', 'Started', 'Part 21'),
#  (140000, 'Machine 2', 'Finished', 'Part 18'),
#  (140000, 'Machine 2', 'Started', 'Part 20'),
#  (140000, 'Machine 4', 'Finished', 'Part 14'),
#  (140000, 'Machine 4', 'Started', 'Part 18'),
#  (140001, 'Machine 1', 'Finished', 'Part 21'),
#  (145000, 'Machine 4', 'Finished', 'Part 18'),
#  (145001, 'Machine 5', 'Finished', 'Part 11'),
#  (145001, 'Machine 5', 'Started', 'Part 15'),
#  (145001, 'Machine 1', 'Started', 'Part 22'),
#  (150000, 'Machine 3', 'Finished', 'Part 16'),
#  (150000, 'Machine 3', 'Started', 'Part 19'),
#  (150000, 'Machine 4', 'Started', 'Part 16'),
#  (150001, 'Machine 1', 'Finished', 'Part 22'),
#  (155000, 'Machine 2', 'Finished', 'Part 20'),
#  (155000, 'Machine 2', 'Started', 'Part 21'),
#  (155000, 'Machine 4', 'Finished', 'Part 16'),
#  (155000, 'Machine 4', 'Started', 'Part 20'),
#  (155001, 'Machine 5', 'Finished', 'Part 15'),
#  (155001, 'Machine 5', 'Started', 'Part 12'),
#  (155001, 'Machine 1', 'Started', 'Part 23'),
#  (160000, 'Machine 4', 'Finished', 'Part 20'),
#  (160001, 'Machine 1', 'Finished', 'Part 23'),
#  (165000, 'Machine 3', 'Finished', 'Part 19'),
#  (165000, 'Machine 3', 'Started', 'Part 22'),
#  (165000, 'Machine 4', 'Started', 'Part 19'),
#  (165001, 'Machine 5', 'Finished', 'Part 12'),
#  (165001, 'Machine 5', 'Started', 'Part 17'),
#  (165001, 'Machine 1', 'Started', 'Part 24'),
#  (170000, 'Machine 2', 'Finished', 'Part 21'),
#  (170000, 'Machine 2', 'Started', 'Part 23'),
#  (170000, 'Machine 4', 'Finished', 'Part 19'),
#  (170000, 'Machine 4', 'Started', 'Part 21'),
#  (170001, 'Machine 1', 'Finished', 'Part 24'),
#  (175000, 'Machine 4', 'Finished', 'Part 21'),
#  (175001, 'Machine 5', 'Finished', 'Part 17'),
#  (175001, 'Machine 5', 'Started', 'Part 14'),
#  (175001, 'Machine 1', 'Started', 'Part 25'),
#  (180000, 'Machine 3', 'Finished', 'Part 22'),
#  (180000, 'Machine 4', 'Started', 'Part 22'),
#  (180001, 'Machine 1', 'Finished', 'Part 25'),
#  (180001, 'Machine 3', 'Started', 'Part 25'),
#  (185000, 'Machine 2', 'Finished', 'Part 23'),
#  (185000, 'Machine 2', 'Started', 'Part 24'),
#  (185000, 'Machine 4', 'Finished', 'Part 22'),
#  (185000, 'Machine 4', 'Started', 'Part 23'),
#  (185001, 'Machine 5', 'Finished', 'Part 14'),
#  (185001, 'Machine 5', 'Started', 'Part 18'),
#  (185001, 'Machine 1', 'Started', 'Part 26'),
#  (190000, 'Machine 4', 'Finished', 'Part 23'),
#  (190001, 'Machine 1', 'Finished', 'Part 26'),
#  (195001, 'Machine 3', 'Finished', 'Part 25'),
#  (195001, 'Machine 5', 'Finished', 'Part 18'),
#  (195001, 'Machine 5', 'Started', 'Part 16'),
#  (195001, 'Machine 1', 'Started', 'Part 27'),
#  (195001, 'Machine 4', 'Started', 'Part 25'),
#  (200000, 'Machine 2', 'Finished', 'Part 24'),
#  (200000, 'Machine 2', 'Started', 'Part 26'),
#  (200001, 'Machine 1', 'Finished', 'Part 27'),
#  (200001, 'Machine 4', 'Finished', 'Part 25'),
#  (200001, 'Machine 4', 'Started', 'Part 24'),
#  (205001, 'Machine 5', 'Finished', 'Part 16'),
#  (205001, 'Machine 5', 'Started', 'Part 20'),
#  (205001, 'Machine 4', 'Finished', 'Part 24'),
#  (205001, 'Machine 1', 'Started', 'Part 28'),
#  (210001, 'Machine 1', 'Finished', 'Part 28'),
#  (210001, 'Machine 3', 'Started', 'Part 28'),
#  (215000, 'Machine 2', 'Finished', 'Part 26'),
#  (215000, 'Machine 2', 'Started', 'Part 27'),
#  (215000, 'Machine 4', 'Started', 'Part 26'),
#  (215001, 'Machine 5', 'Finished', 'Part 20'),
#  (215001, 'Machine 5', 'Started', 'Part 19'),
#  (215001, 'Machine 1', 'Started', 'Part 29'),
#  (220000, 'Machine 4', 'Finished', 'Part 26'),
#  (220001, 'Machine 1', 'Finished', 'Part 29'),
#  (225001, 'Machine 3', 'Finished', 'Part 28'),
#  (225001, 'Machine 5', 'Finished', 'Part 19'),
#  (225001, 'Machine 5', 'Started', 'Part 21'),
#  (225001, 'Machine 1', 'Started', 'Part 30'),
#  (225001, 'Machine 4', 'Started', 'Part 28')]

# %% [markdown]
# Store the timestamp in a vector

# %%
time_sequence = []
for event in events_full_trace:
    time_sequence.append(event[0])
print("time_sequence: ", time_sequence)
# Out:
# time_sequence:  [0, 5000, 5000, 5000, 10000, 10000, 15000, 15000, 15000, 20000, 20000, 20000, 20000, 20000, 25000, 25000, 25000, 25000, 30000, 30000, 30000, 30000, 30000, 35000, 35000, 35000, 35000, 35000, 35000, 35000, 35001, 40000, 40000, 40000, 45000, 45000, 45000, 45000, 45000, 45001, 45001, 50000, 50000, 50000, 50000, 50000, 50000, 55000, 55000, 55000, 55001, 55001, 60000, 60000, 60000, 60000, 60000, 65000, 65000, 65000, 65000, 65000, 65001, 65001, 65001, 70000, 70001, 75000, 75000, 75000, 75001, 75001, 75001, 80000, 80000, 80000, 80000, 80001, 85000, 85001, 85001, 85001, 90000, 90000, 90000, 90001, 95000, 95000, 95000, 95000, 95001, 95001, 95001, 100000, 100001, 105000, 105000, 105000, 105001, 105001, 105001, 110000, 110000, 110000, 110000, 110001, 115000, 115001, 115001, 115001, 120000, 120000, 120000, 120001, 125000, 125000, 125000, 125000, 125001, 125001, 125001, 130000, 130001, 135000, 135000, 135000, 135001, 135001, 135001, 140000, 140000, 140000, 140000, 140001, 145000, 145001, 145001, 145001, 150000, 150000, 150000, 150001, 155000, 155000, 155000, 155000, 155001, 155001, 155001, 160000, 160001, 165000, 165000, 165000, 165001, 165001, 165001, 170000, 170000, 170000, 170000, 170001, 175000, 175001, 175001, 175001, 180000, 180000, 180001, 180001, 185000, 185000, 185000, 185000, 185001, 185001, 185001, 190000, 190001, 195001, 195001, 195001, 195001, 195001, 200000, 200000, 200001, 200001, 200001, 205001, 205001, 205001, 205001, 210001, 210001, 215000, 215000, 215000, 215001, 215001, 215001, 220000, 220001, 225001, 225001, 225001, 225001, 225001]

# %% [markdown]
# Create the string event and store in the vector of events

# %%
events_sequence = []
for event in events_full_trace:
    event_string = event[1] + " - " + event[2]
    events_sequence.append(event_string)
print("Event Sequence")
for event in events_sequence:
    print(event)
# Out:
# Event Sequence
# Machine 1 - Started
# Machine 1 - Finished
# Machine 1 - Started
# Machine 2 - Started
# Machine 1 - Finished
# Machine 1 - Started
# Machine 1 - Finished
# Machine 1 - Started
# Machine 3 - Started
# Machine 2 - Finished
# Machine 2 - Started
# Machine 1 - Finished
# Machine 1 - Started
# Machine 4 - Started
# Machine 1 - Finished
# Machine 1 - Started
# Machine 4 - Finished
# Machine 5 - Started
# Machine 3 - Finished
# Machine 3 - Started
# Machine 1 - Finished
# Machine 1 - Started
# Machine 4 - Started
# Machine 2 - Finished
# Machine 2 - Started
# Machine 5 - Finished
# Machine 1 - Finished
# Machine 1 - Started
# Machine 4 - Finished
# Machine 4 - Started
# Machine 5 - Started
# Machine 1 - Finished
# Machine 1 - Started
# Machine 4 - Finished
# Machine 3 - Finished
# Machine 3 - Started
# Machine 1 - Finished
# Machine 1 - Started
# Machine 4 - Started
# Machine 5 - Finished
# Machine 5 - Started
# Machine 2 - Finished
# Machine 2 - Started
# Machine 1 - Finished
# Machine 1 - Started
# Machine 4 - Finished
# Machine 4 - Started
# Machine 1 - Finished
# Machine 1 - Started
# Machine 4 - Finished
# Machine 5 - Finished
# Machine 5 - Started
# Machine 3 - Finished
# Machine 3 - Started
# Machine 1 - Finished
# Machine 1 - Started
# Machine 4 - Started
# Machine 2 - Finished
# Machine 2 - Started
# Machine 1 - Finished
# Machine 4 - Finished
# Machine 4 - Started
# Machine 5 - Finished
# Machine 5 - Started
# Machine 1 - Started
# Machine 4 - Finished
# Machine 1 - Finished
# Machine 3 - Finished
# Machine 3 - Started
# Machine 4 - Started
# Machine 5 - Finished
# Machine 5 - Started
# Machine 1 - Started
# Machine 2 - Finished
# Machine 2 - Started
# Machine 4 - Finished
# Machine 4 - Started
# Machine 1 - Finished
# Machine 4 - Finished
# Machine 5 - Finished
# Machine 5 - Started
# Machine 1 - Started
# Machine 3 - Finished
# Machine 3 - Started
# Machine 4 - Started
# Machine 1 - Finished
# Machine 2 - Finished
# Machine 2 - Started
# Machine 4 - Finished
# Machine 4 - Started
# Machine 5 - Finished
# Machine 5 - Started
# Machine 1 - Started
# Machine 4 - Finished
# Machine 1 - Finished
# Machine 3 - Finished
# Machine 3 - Started
# Machine 4 - Started
# Machine 5 - Finished
# Machine 5 - Started
# Machine 1 - Started
# Machine 2 - Finished
# Machine 2 - Started
# Machine 4 - Finished
# Machine 4 - Started
# Machine 1 - Finished
# Machine 4 - Finished
# Machine 5 - Finished
# Machine 5 - Started
# Machine 1 - Started
# Machine 3 - Finished
# Machine 3 - Started
# Machine 4 - Started
# Machine 1 - Finished
# Machine 2 - Finished
# Machine 2 - Started
# Machine 4 - Finished
# Machine 4 - Started
# Machine 5 - Finished
# Machine 5 - Started
# Machine 1 - Started
# Machine 4 - Finished
# Machine 1 - Finished
# Machine 3 - Finished
# Machine 3 - Started
# Machine 4 - Started
# Machine 5 - Finished
# Machine 5 - Started
# Machine 1 - Started
# Machine 2 - Finished
# Machine 2 - Started
# Machine 4 - Finished
# Machine 4 - Started
# Machine 1 - Finished
# Machine 4 - Finished
# Machine 5 - Finished
# Machine 5 - Started
# Machine 1 - Started
# Machine 3 - Finished
# Machine 3 - Started
# Machine 4 - Started
# Machine 1 - Finished
# Machine 2 - Finished
# Machine 2 - Started
# Machine 4 - Finished
# Machine 4 - Started
# Machine 5 - Finished
# Machine 5 - Started
# Machine 1 - Started
# Machine 4 - Finished
# Machine 1 - Finished
# Machine 3 - Finished
# Machine 3 - Started
# Machine 4 - Started
# Machine 5 - Finished
# Machine 5 - Started
# Machine 1 - Started
# Machine 2 - Finished
# Machine 2 - Started
# Machine 4 - Finished
# Machine 4 - Started
# Machine 1 - Finished
# Machine 4 - Finished
# Machine 5 - Finished
# Machine 5 - Started
# Machine 1 - Started
# Machine 3 - Finished
# Machine 4 - Started
# Machine 1 - Finished
# Machine 3 - Started
# Machine 2 - Finished
# Machine 2 - Started
# Machine 4 - Finished
# Machine 4 - Started
# Machine 5 - Finished
# Machine 5 - Started
# Machine 1 - Started
# Machine 4 - Finished
# Machine 1 - Finished
# Machine 3 - Finished
# Machine 5 - Finished
# Machine 5 - Started
# Machine 1 - Started
# Machine 4 - Started
# Machine 2 - Finished
# Machine 2 - Started
# Machine 1 - Finished
# Machine 4 - Finished
# Machine 4 - Started
# Machine 5 - Finished
# Machine 5 - Started
# Machine 4 - Finished
# Machine 1 - Started
# Machine 1 - Finished
# Machine 3 - Started
# Machine 2 - Finished
# Machine 2 - Started
# Machine 4 - Started
# Machine 5 - Finished
# Machine 5 - Started
# Machine 1 - Started
# Machine 4 - Finished
# Machine 1 - Finished
# Machine 3 - Finished
# Machine 5 - Finished
# Machine 5 - Started
# Machine 1 - Started
# Machine 4 - Started
