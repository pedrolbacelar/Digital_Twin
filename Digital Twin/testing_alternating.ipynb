# %%
from dtwinpylib.dtwinpy.Digital_Twin import Digital_Twin

import importlib
import dtwinpylib
importlib.reload(dtwinpylib.dtwinpy.Digital_Twin)
# Out:
# <module 'dtwinpylib.dtwinpy.Digital_Twin' from 'c:\\Users\\pedro\\Github_repos\\Digital_Twin\\Digital Twin\\dtwinpylib\\dtwinpy\\Digital_Twin.py'>

# %%
mydt = Digital_Twin(
    name= "5s_alternating",
    maxparts= 5
)
mydt.run_digital_model()
# Out:
# Deleting existing model (excepted by 'initial.json') from the relative folder path:'models/5s_alternating'
# Done! Deleted 0 successfuly
# --- printing databases paths ---
# Digital Database: 'databases/5s_alternating/digital_database.db'
# Real Database: 'databases/5s_alternating/real_database.db'
# ID Database: 'databases/5s_alternating/ID_database.db'
# 22 March 05:57:11 |---- Digital Twin '5s_alternating' created sucessfully ----
# ==========  Reading the Model: 5s_alternating  ==========
# ===> Big Picture
# Total number of Machines: 5
# Total number of Queues: 5
#
# ===>Detailed view of Queues:
# ----------------
# Queue 1
# Arc links: [5, 1]
# Capacity: 10
# |-- Parts stored: Part 1
# |-- Parts stored: Part 2
# |-- Parts stored: Part 3
# Queue Lenght: 3
# ----------------
# Queue 2
# Arc links: [1, 2]
# Capacity: 1
# |-- Parts stored: Part 4
# Queue Lenght: 1
# ----------------
# Queue 3
# Arc links: [2, 3]
# Capacity: 1
# |-- Parts stored: Part 5
# Queue Lenght: 1
# ----------------
# Queue 4
# Arc links: [2, 4]
# Capacity: 1
# |-- Parts stored: Part 6
# Queue Lenght: 1
# ----------------
# Queue 5
# Arc links: None
# Capacity: 2
# Queue Lenght: 0
#
# ===>Detailed view of Machines:
# ----------------
# > Machine 1
# --Queue In:--
# Queue 1
# --Queue Out:--
# Queue 2
# Machine Cluster: 1
# ----------------
# > Machine 2
# --Queue In:--
# Queue 2
# --Queue Out:--
# Queue 3
# Queue 4
# Machine Cluster: 2
# Branching Machine: Branch 1 | Machine 2
# |-- Conveyor towards Queue 3
# |-- Conveyor towards Queue 4
# ----------------
# > Machine 3
# --Queue In:--
# Queue 3
# --Queue Out:--
# Queue 5
# Machine Cluster: 3
# --- Part already being processed: Part 8 ---
# ----------------
# > Machine 4
# --Queue In:--
# Queue 4
# --Queue Out:--
# Queue 5
# Machine Cluster: 3
# --- Part already being processed: Part 7 ---
# ----------------
# > Machine 5
# --Queue In:--
# Queue 5
# --Queue Out:--
# Queue 1
# Machine Cluster: 4
# ### ============ Simulation Started ============ ###
# Time: 0 - [Machine 1] got Part 1 from Queue 1 (capacity= 2)
# Time: 0 - [Machine 2] got Part 4 from Queue 2 (capacity= 0)
# Time: 16 - [Conveyor towards Queue 2] GOT Part 1
# Time: 16 - [Machine 1] got Part 2 from Queue 1 (capacity= 1)
# Time: 28 - [Conveyor towards Queue 2] PUT Part 1 in the Queue 2
# Time: 32 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 2, but all the output queues are full for this machine!
# Time: 34 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 2, but all the output queues are full for this machine!
# Time: 36 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 2, but all the output queues are full for this machine!
# Time: 38 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 2, but all the output queues are full for this machine!
# Time: 40 - [ALL QUEUES FULL] Machine 2 is trying to allocate Part 4, but all the output queues are full for this machine!
# Time: 40 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 2, but all the output queues are full for this machine!
# Time: 42 - [ALL QUEUES FULL] Machine 2 is trying to allocate Part 4, but all the output queues are full for this machine!
# Time: 42 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 2, but all the output queues are full for this machine!
# Time: 44 - [ALL QUEUES FULL] Machine 2 is trying to allocate Part 4, but all the output queues are full for this machine!
# Time: 44 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 2, but all the output queues are full for this machine!
# Time: 46 - [ALL QUEUES FULL] Machine 2 is trying to allocate Part 4, but all the output queues are full for this machine!
# Time: 46 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 2, but all the output queues are full for this machine!
# Time: 48 - [ALL QUEUES FULL] Machine 2 is trying to allocate Part 4, but all the output queues are full for this machine!
# Time: 48 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 2, but all the output queues are full for this machine!
# Time: 50 - [ALL QUEUES FULL] Machine 2 is trying to allocate Part 4, but all the output queues are full for this machine!
# Time: 50 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 2, but all the output queues are full for this machine!
# Time: 52 - [ALL QUEUES FULL] Machine 2 is trying to allocate Part 4, but all the output queues are full for this machine!
# Time: 52 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 2, but all the output queues are full for this machine!
# Time: 54 - [ALL QUEUES FULL] Machine 2 is trying to allocate Part 4, but all the output queues are full for this machine!
# Time: 54 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 2, but all the output queues are full for this machine!
# Time: 56 - [ALL QUEUES FULL] Machine 2 is trying to allocate Part 4, but all the output queues are full for this machine!
# Time: 56 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 2, but all the output queues are full for this machine!
# Time: 58 - [ALL QUEUES FULL] Machine 2 is trying to allocate Part 4, but all the output queues are full for this machine!
# Time: 58 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 2, but all the output queues are full for this machine!
# Time: 60 - [ALL QUEUES FULL] Machine 2 is trying to allocate Part 4, but all the output queues are full for this machine!
# Time: 60 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 2, but all the output queues are full for this machine!
# Time: 62 - [ALL QUEUES FULL] Machine 2 is trying to allocate Part 4, but all the output queues are full for this machine!
# Time: 62 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 2, but all the output queues are full for this machine!
# Time: 64 - [ALL QUEUES FULL] Machine 2 is trying to allocate Part 4, but all the output queues are full for this machine!
# Time: 64 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 2, but all the output queues are full for this machine!
# Time: 66 - [ALL QUEUES FULL] Machine 2 is trying to allocate Part 4, but all the output queues are full for this machine!
# Time: 66 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 2, but all the output queues are full for this machine!
# Time: 68 - [ALL QUEUES FULL] Machine 2 is trying to allocate Part 4, but all the output queues are full for this machine!
# Time: 68 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 2, but all the output queues are full for this machine!
# Time: 70 - [ALL QUEUES FULL] Machine 2 is trying to allocate Part 4, but all the output queues are full for this machine!
# Time: 70 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 2, but all the output queues are full for this machine!
# Time: 72 - [ALL QUEUES FULL] Machine 2 is trying to allocate Part 4, but all the output queues are full for this machine!
# Time: 72 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 2, but all the output queues are full for this machine!
# Time: 74 - [ALL QUEUES FULL] Machine 2 is trying to allocate Part 4, but all the output queues are full for this machine!
# Time: 74 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 2, but all the output queues are full for this machine!
# Time: 76 - [ALL QUEUES FULL] Machine 2 is trying to allocate Part 4, but all the output queues are full for this machine!
# Time: 76 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 2, but all the output queues are full for this machine!
# Time: 78 - [ALL QUEUES FULL] Machine 2 is trying to allocate Part 4, but all the output queues are full for this machine!
# Time: 78 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 2, but all the output queues are full for this machine!
# Time: 79 - [Conveyor towards Queue 5] GOT Part 8
# Time: 79 - [Machine 3] got Part 5 from Queue 3 (capacity= 0)
# Time: 79 - [Conveyor towards Queue 5] GOT Part 7
# Time: 79 - [Machine 4] got Part 6 from Queue 4 (capacity= 0)
# Time: 80 - [Conveyor towards Queue 3] GOT Part 4
# Time: 80 - [Machine 2] got Part 1 from Queue 2 (capacity= 0)
# Time: 80 - [Conveyor towards Queue 2] GOT Part 2
# Time: 80 - [Machine 1] got Part 3 from Queue 1 (capacity= 0)
# Time: 89 - [Conveyor towards Queue 5] PUT Part 8 in the Queue 5
# Time: 89 - [Conveyor towards Queue 5] PUT Part 7 in the Queue 5
# Time: 90 - [Machine 5] got Part 8 from Queue 5 (capacity= 1)
# Time: 92 - [Conveyor towards Queue 2] PUT Part 2 in the Queue 2
# Time: 96 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 3, but all the output queues are full for this machine!
# Time: 98 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 3, but all the output queues are full for this machine!
# Time: 100 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 3, but all the output queues are full for this machine!
# Time: 100 - [Conveyor towards Queue 3] PUT Part 4 in the Queue 3
# Time: 102 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 3, but all the output queues are full for this machine!
# Time: 104 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 3, but all the output queues are full for this machine!
# Time: 106 - [Terminator] xxx Part 8 terminated xxx
# Time: 106 - [Terminator] Part 9 replaced
# Time: 106 - [Conveyor towards Queue 1] GOT Part 9
# Time: 106 - [Machine 5] got Part 7 from Queue 5 (capacity= 0)
# Time: 106 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 3, but all the output queues are full for this machine!
# Time: 108 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 3, but all the output queues are full for this machine!
# Time: 110 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 3, but all the output queues are full for this machine!
# Time: 112 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 3, but all the output queues are full for this machine!
# Time: 114 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 3, but all the output queues are full for this machine!
# Time: 116 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 3, but all the output queues are full for this machine!
# Time: 116 - [Conveyor towards Queue 1] PUT Part 9 in the Queue 1
# Time: 118 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 3, but all the output queues are full for this machine!
# Time: 120 - [Conveyor towards Queue 4] GOT Part 1
# Time: 120 - [Machine 2] got Part 2 from Queue 2 (capacity= 0)
# Time: 120 - [Conveyor towards Queue 2] GOT Part 3
# Time: 120 - [Machine 1] got Part 9 from Queue 1 (capacity= 0)
# Time: 122 - [Terminator] xxx Part 7 terminated xxx
# Time: 122 - [Terminator] Part 10 replaced
# Time: 122 - [Conveyor towards Queue 1] GOT Part 10
# Time: 132 - [Conveyor towards Queue 2] PUT Part 3 in the Queue 2
# Time: 132 - [Conveyor towards Queue 1] PUT Part 10 in the Queue 1
# Time: 136 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 9, but all the output queues are full for this machine!
# Time: 138 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 9, but all the output queues are full for this machine!
# Time: 140 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 9, but all the output queues are full for this machine!
# Time: 140 - [Conveyor towards Queue 4] PUT Part 1 in the Queue 4
# Time: 142 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 9, but all the output queues are full for this machine!
# Time: 144 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 9, but all the output queues are full for this machine!
# Time: 146 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 9, but all the output queues are full for this machine!
# Time: 148 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 9, but all the output queues are full for this machine!
# Time: 150 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 9, but all the output queues are full for this machine!
# Time: 152 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 9, but all the output queues are full for this machine!
# Time: 154 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 9, but all the output queues are full for this machine!
# Time: 156 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 9, but all the output queues are full for this machine!
# Time: 158 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 9, but all the output queues are full for this machine!
# Time: 159 - [Conveyor towards Queue 5] GOT Part 5
# Time: 159 - [Machine 3] got Part 4 from Queue 3 (capacity= 0)
# Time: 159 - [Conveyor towards Queue 5] GOT Part 6
# Time: 159 - [Machine 4] got Part 1 from Queue 4 (capacity= 0)
# Time: 160 - [Conveyor towards Queue 4] GOT Part 2
# Time: 160 - [Machine 2] got Part 3 from Queue 2 (capacity= 0)
# Time: 160 - [Conveyor towards Queue 2] GOT Part 9
# Time: 160 - [Machine 1] got Part 10 from Queue 1 (capacity= 0)
# Time: 169 - [Conveyor towards Queue 5] PUT Part 5 in the Queue 5
# Time: 169 - [Conveyor towards Queue 5] PUT Part 6 in the Queue 5
# Time: 170 - [Machine 5] got Part 5 from Queue 5 (capacity= 1)
# Time: 172 - [Conveyor towards Queue 2] PUT Part 9 in the Queue 2
# Time: 176 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 10, but all the output queues are full for this machine!
# Time: 178 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 10, but all the output queues are full for this machine!
# Time: 180 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 10, but all the output queues are full for this machine!
# Time: 180 - [Conveyor towards Queue 4] PUT Part 2 in the Queue 4
# Time: 182 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 10, but all the output queues are full for this machine!
# Time: 184 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 10, but all the output queues are full for this machine!
# Time: 186 - [Terminator] xxx Part 5 terminated xxx
# Time: 186 - [Terminator] Part 11 replaced
# Time: 186 - [Conveyor towards Queue 1] GOT Part 11
# Time: 186 - [Machine 5] got Part 6 from Queue 5 (capacity= 0)
# Time: 186 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 10, but all the output queues are full for this machine!
# Time: 188 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 10, but all the output queues are full for this machine!
# Time: 190 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 10, but all the output queues are full for this machine!
# Time: 192 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 10, but all the output queues are full for this machine!
# Time: 194 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 10, but all the output queues are full for this machine!
# Time: 196 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 10, but all the output queues are full for this machine!
# Time: 196 - [Conveyor towards Queue 1] PUT Part 11 in the Queue 1
# Time: 198 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 10, but all the output queues are full for this machine!
# Time: 200 - [ALL QUEUES FULL] Machine 2 is trying to allocate Part 3, but all the output queues are full for this machine!
# Time: 200 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 10, but all the output queues are full for this machine!
# Time: 202 - [Terminator] xxx Part 6 terminated xxx
# Time: 202 - [Terminator] Part 12 replaced
# Time: 202 - [Conveyor towards Queue 1] GOT Part 12
# Time: 202 - [Conveyor towards Queue 3] GOT Part 3
# Time: 202 - [Machine 2] got Part 9 from Queue 2 (capacity= 0)
# Time: 202 - [Conveyor towards Queue 2] GOT Part 10
# Time: 202 - [Machine 1] got Part 11 from Queue 1 (capacity= 0)
# Time: 212 - [Conveyor towards Queue 1] PUT Part 12 in the Queue 1
# Time: 214 - [Conveyor towards Queue 2] PUT Part 10 in the Queue 2
# Time: 218 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 11, but all the output queues are full for this machine!
# Time: 220 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 11, but all the output queues are full for this machine!
# Time: 222 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 11, but all the output queues are full for this machine!
# Time: 222 - [Conveyor towards Queue 3] PUT Part 3 in the Queue 3
# Time: 224 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 11, but all the output queues are full for this machine!
# Time: 226 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 11, but all the output queues are full for this machine!
# Time: 228 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 11, but all the output queues are full for this machine!
# Time: 230 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 11, but all the output queues are full for this machine!
# Time: 232 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 11, but all the output queues are full for this machine!
# Time: 234 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 11, but all the output queues are full for this machine!
# Time: 236 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 11, but all the output queues are full for this machine!
# Time: 238 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 11, but all the output queues are full for this machine!
# Time: 239 - [Conveyor towards Queue 5] GOT Part 4
# Time: 239 - [Machine 3] got Part 3 from Queue 3 (capacity= 0)
# Time: 239 - [Conveyor towards Queue 5] GOT Part 1
# Time: 239 - [Machine 4] got Part 2 from Queue 4 (capacity= 0)
# Time: 240 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 11, but all the output queues are full for this machine!
# Time: 242 - [Conveyor towards Queue 3] GOT Part 9
# Time: 242 - [Machine 2] got Part 10 from Queue 2 (capacity= 0)
# Time: 242 - [Conveyor towards Queue 2] GOT Part 11
# Time: 242 - [Machine 1] got Part 12 from Queue 1 (capacity= 0)
# Time: 249 - [Conveyor towards Queue 5] PUT Part 4 in the Queue 5
# Time: 249 - [Conveyor towards Queue 5] PUT Part 1 in the Queue 5
# Time: 250 - [Machine 5] got Part 4 from Queue 5 (capacity= 1)
# Time: 254 - [Conveyor towards Queue 2] PUT Part 11 in the Queue 2
# Time: 258 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 12, but all the output queues are full for this machine!
# Time: 260 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 12, but all the output queues are full for this machine!
# Time: 262 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 12, but all the output queues are full for this machine!
# Time: 262 - [Conveyor towards Queue 3] PUT Part 9 in the Queue 3
# Time: 264 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 12, but all the output queues are full for this machine!
# Time: 266 - [Terminator] xxx Part 4 terminated xxx
# Time: 266 - [Terminator] Part 13 replaced
# Time: 266 - [Conveyor towards Queue 1] GOT Part 13
# Time: 266 - [Machine 5] got Part 1 from Queue 5 (capacity= 0)
# Time: 266 - [ALL QUEUES FULL] Machine 1 is trying to allocate Part 12, but all the output queues are full for this machine!
# === Reading all the events from table: digital_log ===
# (1, 0, 'Machine 1', 'Started', 'Part 1', 'Queue 1', None, None)
# (2, 0, 'Machine 2', 'Started', 'Part 4', 'Queue 2', None, None)
# (3, 16, 'Machine 1', 'Finished', 'Part 1', 'Queue 2', None, None)
# (4, 16, 'Machine 1', 'Started', 'Part 2', 'Queue 1', None, None)
# (5, 79, 'Machine 3', 'Finished', 'Part 8', 'Queue 5', None, None)
# (6, 79, 'Machine 3', 'Started', 'Part 5', 'Queue 3', None, None)
# (7, 79, 'Machine 4', 'Finished', 'Part 7', 'Queue 5', None, None)
# (8, 79, 'Machine 4', 'Started', 'Part 6', 'Queue 4', None, None)
# (9, 80, 'Machine 2', 'Finished', 'Part 4', 'Queue 3', None, None)
# (10, 80, 'Machine 2', 'Started', 'Part 1', 'Queue 2', None, None)
# (11, 80, 'Machine 1', 'Finished', 'Part 2', 'Queue 2', None, None)
# (12, 80, 'Machine 1', 'Started', 'Part 3', 'Queue 1', None, None)
# (13, 90, 'Machine 5', 'Started', 'Part 8', 'Queue 5', None, None)
# (14, 106, 'Machine 5', 'Finished', 'Part 8', 'Queue 1', None, None)
# (15, 106, 'Machine 5', 'Started', 'Part 7', 'Queue 5', None, None)
# (16, 120, 'Machine 2', 'Finished', 'Part 1', 'Queue 4', None, None)
# (17, 120, 'Machine 2', 'Started', 'Part 2', 'Queue 2', None, None)
# (18, 120, 'Machine 1', 'Finished', 'Part 3', 'Queue 2', None, None)
# (19, 120, 'Machine 1', 'Started', 'Part 9', 'Queue 1', None, None)
# (20, 122, 'Machine 5', 'Finished', 'Part 7', 'Queue 1', None, None)
# (21, 159, 'Machine 3', 'Finished', 'Part 5', 'Queue 5', None, None)
# (22, 159, 'Machine 3', 'Started', 'Part 4', 'Queue 3', None, None)
# (23, 159, 'Machine 4', 'Finished', 'Part 6', 'Queue 5', None, None)
# (24, 159, 'Machine 4', 'Started', 'Part 1', 'Queue 4', None, None)
# (25, 160, 'Machine 2', 'Finished', 'Part 2', 'Queue 4', None, None)
# (26, 160, 'Machine 2', 'Started', 'Part 3', 'Queue 2', None, None)
# (27, 160, 'Machine 1', 'Finished', 'Part 9', 'Queue 2', None, None)
# (28, 160, 'Machine 1', 'Started', 'Part 10', 'Queue 1', None, None)
# (29, 170, 'Machine 5', 'Started', 'Part 5', 'Queue 5', None, None)
# (30, 186, 'Machine 5', 'Finished', 'Part 5', 'Queue 1', None, None)
# (31, 186, 'Machine 5', 'Started', 'Part 6', 'Queue 5', None, None)
# (32, 202, 'Machine 5', 'Finished', 'Part 6', 'Queue 1', None, None)
# (33, 202, 'Machine 2', 'Finished', 'Part 3', 'Queue 3', None, None)
# (34, 202, 'Machine 2', 'Started', 'Part 9', 'Queue 2', None, None)
# (35, 202, 'Machine 1', 'Finished', 'Part 10', 'Queue 2', None, None)
# (36, 202, 'Machine 1', 'Started', 'Part 11', 'Queue 1', None, None)
# (37, 239, 'Machine 3', 'Finished', 'Part 4', 'Queue 5', None, None)
# (38, 239, 'Machine 3', 'Started', 'Part 3', 'Queue 3', None, None)
# (39, 239, 'Machine 4', 'Finished', 'Part 1', 'Queue 5', None, None)
# (40, 239, 'Machine 4', 'Started', 'Part 2', 'Queue 4', None, None)
# (41, 242, 'Machine 2', 'Finished', 'Part 9', 'Queue 3', None, None)
# (42, 242, 'Machine 2', 'Started', 'Part 10', 'Queue 2', None, None)
# (43, 242, 'Machine 1', 'Finished', 'Part 11', 'Queue 2', None, None)
# (44, 242, 'Machine 1', 'Started', 'Part 12', 'Queue 1', None, None)
# (45, 250, 'Machine 5', 'Started', 'Part 4', 'Queue 5', None, None)
# (46, 266, 'Machine 5', 'Finished', 'Part 4', 'Queue 1', None, None)
# (47, 266, 'Machine 5', 'Started', 'Part 1', 'Queue 5', None, None)
# ### ============ Simulation Done ============ ###
# ================ Running Analysis ================
# Number of Parts finished: 5
# Total time of Simulation: 266
# - Maximum Cycle Time: 266
# - Minimum Cycle Time: 106
# >>> Average system cycle time: 176.4 [time unit]***
# >>> System Throughput: 0.018796992481203006 [parts / time unit]
