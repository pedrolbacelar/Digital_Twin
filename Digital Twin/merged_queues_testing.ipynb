# %% [markdown]
# # Testing Merging Input Queues
# This testings aims to verify if the merging of input queues is working

# %%
from dtwinpylib.dtwinpy.Digital_Twin import Digital_Twin

import importlib
import dtwinpylib
importlib.reload(dtwinpylib.dtwinpy.Digital_Twin) #reload this specifc module to upadte the class
# Out:
# <module 'dtwinpylib.dtwinpy.Digital_Twin' from 'c:\\Users\\pedro\\Github Repositories\\Digital_Twin\\Digital Twin\\dtwinpylib\\dtwinpy\\Digital_Twin.py'>

# %% [markdown]
# #### 5-s Model

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
digital_twin = Digital_Twin(name="5s_merging")
digital_model = digital_twin.generate_digital_model()
# Out:
# ==========  Reading the Model: 5s_merging  ==========
# ===> Big Picture
# Total number of Machines: 5
# Total number of Queues: 5
#
# ===>Detailed view of Queues:
# ----------------
# Queue 1
# Arc links: [5, 1]
# Capacity: 10
# Queue Lenght: 0
# ----------------
# Queue 2
# Arc links: [1, 2]
# Capacity: 10
# Queue Lenght: 0
# ----------------
# Queue 3
# Arc links: [1, 3]
# Capacity: 10
# Queue Lenght: 0
# ----------------
# Queue 4
# Arc links: None
# Capacity: 20
# Queue Lenght: 0
# ----------------
# Queue 5
# Arc links: [4, 5]
# Capacity: 10
# Parts stored: Part 1
# Part Processes for Trace Driven Simulation: None
# Parts stored: Part 2
# Part Processes for Trace Driven Simulation: None
# Parts stored: Part 3
# Part Processes for Trace Driven Simulation: None
# Parts stored: Part 4
# Part Processes for Trace Driven Simulation: None
# Parts stored: Part 5
# Part Processes for Trace Driven Simulation: None
# Parts stored: Part 6
# Part Processes for Trace Driven Simulation: None
# Parts stored: Part 7
# Part Processes for Trace Driven Simulation: None
# Parts stored: Part 8
# Part Processes for Trace Driven Simulation: None
# Parts stored: Part 9
# Part Processes for Trace Driven Simulation: None
# Parts stored: Part 10
# Part Processes for Trace Driven Simulation: None
# Queue Lenght: 10
#
# ===>Detailed view of Machines:
# ----------------
# > Machine 1
# --Queue In:--
# Queue 1
# --Queue Out:--
# Queue 2
# Queue 3
# ---Process Time for quasi Trace Driven Simulation---
# None
# ----------------
# > Machine 2
# --Queue In:--
# Queue 2
# --Queue Out:--
# Queue 4
# ---Process Time for quasi Trace Driven Simulation---
# None
# ----------------
# > Machine 3
# --Queue In:--
# Queue 3
# --Queue Out:--
# Queue 4
# ---Process Time for quasi Trace Driven Simulation---
# None
# ----------------
# > Machine 4
# --Queue In:--
# Queue 4
# --Queue Out:--
# Queue 5
# ---Process Time for quasi Trace Driven Simulation---
# None
# ----------------
# > Machine 5
# --Queue In:--
# Queue 5
# --Queue Out:--
# Queue 1
# ---Process Time for quasi Trace Driven Simulation---
# None

# %% [markdown]
# Show the order of Queues in Queues Vector

# %%
(machines_vector, queues_vector) = digital_model.get_model_components()
for queue in queues_vector:
    print(queue.get_name())
# Out:
# Queue 1
# Queue 2
# Queue 3
# Queue 4
# Queue 5

# %% [markdown]
# #### Non-parallel complex

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image-2.png)

# %%
digital_twin = Digital_Twin(
    name= "merging_non_parallel"
)
digital_model = digital_twin.generate_digital_model()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       1 digital_twin = Digital_Twin(
#       2     name= "merging_non_parallel"
#       3 )
# ----> 4 digital_model = digital_twin.generate_digital_model()
#
# File c:\Users\pedro\Github Repositories\Digital_Twin\Digital Twin\dtwinpylib\dtwinpy\Digital_Twin.py:38, in Digital_Twin.generate_digital_model(self)
#      36 def generate_digital_model(self):
#      37     self.digital_model = Model(name= self.name,model_path= self.model_path, database_path= self.database_path, until= self.until, initial= self.initial, loop_type= self.loop_type, maxparts= self.maxparts)
# ---> 38     self.digital_model.model_translator()
#      39     self.digital_model.verbose()
#      41     return self.digital_model
#
# File c:\Users\pedro\Github Repositories\Digital_Twin\Digital Twin\dtwinpylib\dtwinpy\digital_model.py:216, in Model.model_translator(self)
#     209     self.queue_allocation()
#     210     #====================================================================
#     211
#     212
#     213 ###### Do the initial allocation after the merge, so we don't have problems with the number of queue
#     214 # being different than the number of positions in initial allocation vector
#     215 # The initial allocation could even be a dictionary
# --> 216 self.merge_queues()
#     218 #========================= Initial Allocation ===================
#     219 if self.initial == True:
#     220     #--- Allocate the initial Parts for each Queue
#
# File c:\Users\pedro\Github Repositories\Digital_Twin\Digital Twin\dtwinpylib\dtwinpy\digital_model.py:109, in Model.merge_queues(self)
#     105 merged_queues_all = []
#     107 for machine in self.machines_vector:
#     108     #--- Machine with multiple queues
# --> 109     if len(machine.get_queue_in()) > 1:
#     110         #--- Create the vectors with Queues to be merge
#     111         queues_to_merge = machine.get_queue_in()
#     112         queue_to_merge_all.append(queues_to_merge)
#
# TypeError: object of type 'NoneType' has no len()
