# %% [markdown]
# ## Digital Twin Shor Demo 0.0.3.6

# %% [markdown]
# ### How to install the library?
#
# Take the path of the folder named 'dtwinpy-0.0.3.6-py3-none-any.whl' and use pip:
#
# ```
# python -m pip install "C:\Users\pedro\Github_repos\Digital_Twin\Digital Twin\dtwinpylib\dist\dtwinpy-0.0.3.6-py3-none-any.whl"
# ```

# %% [markdown]
# ### Important News:
# - Now you need to put your model json inside of a folder 'models' in the root and within that folder, inside of another folder named as your Digital Twin (models/my_dt_name/).
# - Your model need to have name as 'initial.json'. So in the end you have: ('models/mydt_name/initial.json')
# - The machine 2 is now the branching machine

# %% [markdown]
# ## My first DT

# %% [markdown]
# Importing the library

# %%
from dtwinpylib.dtwinpy.Digital_Twin import Digital_Twin
# Out:
# Model imported...
# Validator imported...
# Database imported...
# Synchronizer imported...
# Service_Handler imported...
# Broker_Manager imported...
# Helper imported...
# interfaceAPI imported...
# Updator imported...
# 'dtwinpy' version being used: 0.0.3.7

# %% [markdown]
# Create your first DT

# %%
mydt = Digital_Twin(name= '5s_determ')
# Out:
# Deleting existing model (excepted by 'initial.json') from the relative folder path:'models/5s_determ'
# Done! Deleted 0 successfuly
# --- printing databases paths ---
# Digital Database: 'databases/5s_determ/digital_database.db'
# Real Database: 'databases/5s_determ/real_database.db'
# ID Database: 'databases/5s_determ/ID_database.db'
# IP address not provided, Broker Manager not created. Considering an offiline enviorment
# 27 March 18:32:25 |---- Digital Twin '5s_determ' created sucessfully ----

# %% [markdown]
# ### Simple Simulations

# %% [markdown]
# Running a simple simulation to finish 5 parts

# %%
mydt.run_digital_model(maxparts=5, plot= False)
# Out:
# ==========  Reading the Model: 5s_determ  ==========
# ===> Big Picture
# Total number of Machines: 5
# Total number of Queues: 5
#
# ===>Detailed view of Queues:
# ----------------
# Queue 1
# Arc links: [5, 1]
# Capacity: 12
# |-- Parts stored: Part 13
# Queue Lenght: 1
# ----------------
# Queue 2
# Arc links: [1, 2]
# Capacity: 10
# Queue Lenght: 0
# ----------------
# Queue 3
# Arc links: [2, 3]
# Capacity: 10
# Queue Lenght: 0
# ----------------
# Queue 4
# Arc links: [2, 4]
# Capacity: 10
# Queue Lenght: 0
# ----------------
# Queue 5
# Arc links: None
# Capacity: 20
# Queue Lenght: 0
#
# ===>Detailed view of Machines:
# ----------------
# > Machine 1
# --Queue In:--
# Queue 1
# --Queue Out:--
# Queue 2
# Machine Cluster: 1
# ----------------
# > Machine 2
# --Queue In:--
# Queue 2
# --Queue Out:--
# Queue 3
# Queue 4
# Machine Cluster: 2
# Branching Machine: Branch 1 | Machine 2
# |-- Conveyor towards Queue 3
# |-- Conveyor towards Queue 4
# ----------------
# > Machine 3
# --Queue In:--
# Queue 3
# --Queue Out:--
# Queue 5
# Machine Cluster: 3
# ----------------
# > Machine 4
# --Queue In:--
# Queue 4
# --Queue Out:--
# Queue 5
# Machine Cluster: 3
# ----------------
# > Machine 5
# --Queue In:--
# Queue 5
# --Queue Out:--
# Queue 1
# Machine Cluster: 4
# ### ============ Simulation Started ============ ###
# Time: 0 - [Machine 1] got Part 13 from Queue 1 (capacity= 0)
# ! Using 'alternated' policy to allocate Part
from Queue 2 (capacity= 0)
# ! Using 'alternated' policy to allocate Part 16 to Queue 4
# Time: 483 - [Conveyor towards Queue 4] GOT Part 16
# Time: 503 - [Conveyor towards Queue 4] PUT Part 16 in the Queue 4
# Time: 504 - [Machine 4] got Part 16 from Queue 4 (capacity= 0)
# ! Using 'alternated' policy to allocate Part 16 to Queue 5
# Time: 542 - [Conveyor towards Queue 5] GOT Part 16
# Time: 553 - [Conveyor towards Queue 5] PUT Part 16 in the Queue 5
# Time: 554 - [Machine 5] got Part 16 from Queue 5 (capacity= 0)
# ! Using 'alternated' policy to allocate Part 16 to Queue 1
# Time: 564 - [Terminator] xxx Part 16 terminated xxx
# Time: 564 - [Terminator] Part 17 replaced
# Time: 564 - [Conveyor towards Queue 1] GOT Part 17
# Time: 573 - [Conveyor towards Queue 1] PUT Part 17 in the Queue 1
# Time: 574 - [Machine 1] got Part 17 from Queue 1 (capacity= 0)
# ! Using 'alternated' policy to allocate Part 17 to Queue 2
# Time: 585 - [Conveyor towards Queue 2] GOT Part 17
# Time: 596 - [Conveyor towards Queue 2] PUT Part 17 in the Queue 2
# Time: 597 - [Machine 2] got Part 17 from Queue 2 (capacity= 0)
# ! Using 'alternated' policy to allocate Part 17 to Queue 3
# Time: 614 - [Conveyor towards Queue 3] GOT Part 17
# Time: 637 - [Conveyor towards Queue 3] PUT Part 17 in the Queue 3
# Time: 638 - [Machine 3] got Part 17 from Queue 3 (capacity= 0)
# ! Using 'alternated' policy to allocate Part 17 to Queue 5
# Time: 698 - [Conveyor towards Queue 5] GOT Part 17
# Time: 709 - [Conveyor towards Queue 5] PUT Part 17 in the Queue 5
# Time: 710 - [Machine 5] got Part 17 from Queue 5 (capacity= 0)
# ! Using 'alternated' policy to allocate Part 17 to Queue 1
# Time: 720 - [Terminator] xxx Part 17 terminated xxx
# Time: 720 - [Terminator] Part 18 replaced
# Time: 720 - [Conveyor towards Queue 1] GOT Part 18
# === Reading all the events from table: digital_log ===
# (1, 0, 'Machine 1', 'Started', 'Part 13', 'Queue 1', None, None)
# (2, 11, 'Machine 1', 'Finished', 'Part 13', 'Queue 2', None, None)
# (3, 23, 'Machine 2', 'Started', 'Part 13', 'Queue 2', None, None)
# (4, 40, 'Machine 2', 'Finished', 'Part 13', 'Queue 3', None, None)
# (5, 64, 'Machine 3', 'Started', 'Part 13', 'Queue 3', None, None)
# (6, 124, 'Machine 3', 'Finished', 'Part 13', 'Queue 5', None, None)
# (7, 136, 'Machine 5', 'Started', 'Part 13', 'Queue 5', None, None)
# (8, 146, 'Machine 5', 'Finished', 'Part 13', 'Queue 1', None, None)
# (9, 156, 'Machine 1', 'Started', 'Part 14', 'Queue 1', None, None)
# (10, 167, 'Machine 1', 'Finished', 'Part 14', 'Queue 2', None, None)
# (11, 179, 'Machine 2', 'Started', 'Part 14', 'Queue 2', None, None)
# (12, 196, 'Machine 2', 'Finished', 'Part 14', 'Queue 4', None, None)
# (13, 217, 'Machine 4', 'Started', 'Part 14', 'Queue 4', None, None)
# (14, 255, 'Machine 4', 'Finished', 'Part 14', 'Queue 5', None, None)
# (15, 267, 'Machine 5', 'Started', 'Part 14', 'Queue 5', None, None)
# (16, 277, 'Machine 5', 'Finished', 'Part 14', 'Queue 1', None, None)
# (17, 287, 'Machine 1', 'Started', 'Part 15', 'Queue 1', None, None)
# (18, 298, 'Machine 1', 'Finished', 'Part 15', 'Queue 2', None, None)
# (19, 310, 'Machine 2', 'Started', 'Part 15', 'Queue 2', None, None)
# (20, 327, 'Machine 2', 'Finished', 'Part 15', 'Queue 3', None, None)
# (21, 351, 'Machine 3', 'Started', 'Part 15', 'Queue 3', None, None)
# (22, 411, 'Machine 3', 'Finished', 'Part 15', 'Queue 5', None, None)
# (23, 423, 'Machine 5', 'Started', 'Part 15', 'Queue 5', None, None)
# (24, 433, 'Machine 5', 'Finished', 'Part 15', 'Queue 1', None, None)
# (25, 443, 'Machine 1', 'Started', 'Part 16', 'Queue 1', None, None)
# (26, 454, 'Machine 1', 'Finished', 'Part 16', 'Queue 2', None, None)
# (27, 466, 'Machine 2', 'Started', 'Part 16', 'Queue 2', None, None)
# (28, 483, 'Machine 2', 'Finished', 'Part 16', 'Queue 4', None, None)
# (29, 504, 'Machine 4', 'Started', 'Part 16', 'Queue 4', None, None)
# (30, 542, 'Machine 4', 'Finished', 'Part 16', 'Queue 5', None, None)
# (31, 554, 'Machine 5', 'Started', 'Part 16', 'Queue 5', None, None)
# (32, 564, 'Machine 5', 'Finished', 'Part 16', 'Queue 1', None, None)
# (33, 574, 'Machine 1', 'Started', 'Part 17', 'Queue 1', None, None)
# (34, 585, 'Machine 1', 'Finished', 'Part 17', 'Queue 2', None, None)
# (35, 597, 'Machine 2', 'Started', 'Part 17', 'Queue 2', None, None)
# (36, 614, 'Machine 2', 'Finished', 'Part 17', 'Queue 3', None, None)
# (37, 638, 'Machine 3', 'Started', 'Part 17', 'Queue 3', None, None)
# (38, 698, 'Machine 3', 'Finished', 'Part 17', 'Queue 5', None, None)
# (39, 710, 'Machine 5', 'Started', 'Part 17', 'Queue 5', None, None)
# (40, 720, 'Machine 5', 'Finished', 'Part 17', 'Queue 1', None, None)
# ### ============ Simulation Done ============ ###

# %% [markdown]
# Running for a targeted part id to finish the simulation

# %%
mydt.run_digital_model(targeted_part_id= 2)
# Out:
# ==========  Reading the Model: 5s_determ  ==========
# ===> Big Picture
# Total number of Machines: 5
# Total number of Queues: 5
#
# ===>Detailed view of Queues:
# ----------------
# Queue 1
# Arc links: [5, 1]
# Capacity: 12
# |-- Parts stored: Part 13
# Queue Lenght: 1
# ----------------
# Queue 2
# Arc links: [1, 2]
# Capacity: 10
# Queue Lenght: 0
# ----------------
# Queue 3
# Arc links: [2, 3]
# Capacity: 10
# Queue Lenght: 0
# ----------------
# Queue 4
# Arc links: [2, 4]
# Capacity: 10
# Queue Lenght: 0
# ----------------
# Queue 5
# Arc links: None
# Capacity: 20
# Queue Lenght: 0
#
# ===>Detailed view of Machines:
# ----------------
# > Machine 1
# --Queue In:--
# Queue 1
# --Queue Out:--
# Queue 2
# Machine Cluster: 1
# ----------------
# > Machine 2
# --Queue In:--
# Queue 2
# --Queue Out:--
# Queue 3
# Queue 4
# Machine Cluster: 2
# Branching Machine: Branch 1 | Machine 2
# |-- Conveyor towards Queue 3
# |-- Conveyor towards Queue 4
# ----------------
# > Machine 3
# --Queue In:--
# Queue 3
# --Queue Out:--
# Queue 5
# Machine Cluster: 3
# ----------------
# > Machine 4
# --Queue In:--
# Queue 4
# --Queue Out:--
# Queue 5
# Machine Cluster: 3
# ----------------
# > Machine 5
# --Queue In:--
# Queue 5
# --Queue Out:--
# Queue 1
# Machine Cluster: 4
# ### ============ Simulation Started ============ ###
# Time: 0 - [Machine 1] got Part 13 from Queue 1 (capacity= 0)
# ! Using 'alternated' policy to allocate Part
from Queue 2 (capacity= 0)
# ! Using 'alternated' policy to allocate Part 16 to Queue 4
# Time: 483 - [Conveyor towards Queue 4] GOT Part 16
# Time: 503 - [Conveyor towards Queue 4] PUT Part 16 in the Queue 4
# Time: 504 - [Machine 4] got Part 16 from Queue 4 (capacity= 0)
# ! Using 'alternated' policy to allocate Part 16 to Queue 5
# Time: 542 - [Conveyor towards Queue 5] GOT Part 16
# Time: 553 - [Conveyor towards Queue 5] PUT Part 16 in the Queue 5
# Time: 554 - [Machine 5] got Part 16 from Queue 5 (capacity= 0)
# ! Using 'alternated' policy to allocate Part 16 to Queue 1
# Time: 564 - [Terminator] xxx Part 16 terminated xxx
# Time: 564 - [Terminator] Part 17 replaced
# Time: 564 - [Conveyor towards Queue 1] GOT Part 17
# Time: 573 - [Conveyor towards Queue 1] PUT Part 17 in the Queue 1
# Time: 574 - [Machine 1] got Part 17 from Queue 1 (capacity= 0)
# ! Using 'alternated' policy to allocate Part 17 to Queue 2
# Time: 585 - [Conveyor towards Queue 2] GOT Part 17
# Time: 596 - [Conveyor towards Queue 2] PUT Part 17 in the Queue 2
# Time: 597 - [Machine 2] got Part 17 from Queue 2 (capacity= 0)
# ! Using 'alternated' policy to allocate Part 17 to Queue 3
# Time: 614 - [Conveyor towards Queue 3] GOT Part 17
# Time: 637 - [Conveyor towards Queue 3] PUT Part 17 in the Queue 3
# Time: 638 - [Machine 3] got Part 17 from Queue 3 (capacity= 0)
# ! Using 'alternated' policy to allocate Part 17 to Queue 5
# Time: 698 - [Conveyor towards Queue 5] GOT Part 17
# Time: 709 - [Conveyor towards Queue 5] PUT Part 17 in the Queue 5
# Time: 710 - [Machine 5] got Part 17 from Queue 5 (capacity= 0)
# ! Using 'alternated' policy to allocate Part 17 to Queue 1
# Time: 720 - [Terminator] xxx Part 17 terminated xxx
# Time: 720 - [Terminator] Part 18 replaced
# Time: 720 - [Conveyor towards Queue 1] GOT Part 18
# === Reading all the events from table: digital_log ===
# (1, 0, 'Machine 1', 'Started', 'Part 13', 'Queue 1', None, None)
# (2, 11, 'Machine 1', 'Finished', 'Part 13', 'Queue 2', None, None)
# (3, 23, 'Machine 2', 'Started', 'Part 13', 'Queue 2', None, None)
# (4, 40, 'Machine 2', 'Finished', 'Part 13', 'Queue 3', None, None)
# (5, 64, 'Machine 3', 'Started', 'Part 13', 'Queue 3', None, None)
# (6, 124, 'Machine 3', 'Finished', 'Part 13', 'Queue 5', None, None)
# (7, 136, 'Machine 5', 'Started', 'Part 13', 'Queue 5', None, None)
# (8, 146, 'Machine 5', 'Finished', 'Part 13', 'Queue 1', None, None)
# (9, 156, 'Machine 1', 'Started', 'Part 14', 'Queue 1', None, None)
# (10, 167, 'Machine 1', 'Finished', 'Part 14', 'Queue 2', None, None)
# (11, 179, 'Machine 2', 'Started', 'Part 14', 'Queue 2', None, None)
# (12, 196, 'Machine 2', 'Finished', 'Part 14', 'Queue 4', None, None)
# (13, 217, 'Machine 4', 'Started', 'Part 14', 'Queue 4', None, None)
# (14, 255, 'Machine 4', 'Finished', 'Part 14', 'Queue 5', None, None)
# (15, 267, 'Machine 5', 'Started', 'Part 14', 'Queue 5', None, None)
# (16, 277, 'Machine 5', 'Finished', 'Part 14', 'Queue 1', None, None)
# (17, 287, 'Machine 1', 'Started', 'Part 15', 'Queue 1', None, None)
# (18, 298, 'Machine 1', 'Finished', 'Part 15', 'Queue 2', None, None)
# (19, 310, 'Machine 2', 'Started', 'Part 15', 'Queue 2', None, None)
# (20, 327, 'Machine 2', 'Finished', 'Part 15', 'Queue 3', None, None)
# (21, 351, 'Machine 3', 'Started', 'Part 15', 'Queue 3', None, None)
# (22, 411, 'Machine 3', 'Finished', 'Part 15', 'Queue 5', None, None)
# (23, 423, 'Machine 5', 'Started', 'Part 15', 'Queue 5', None, None)
# (24, 433, 'Machine 5', 'Finished', 'Part 15', 'Queue 1', None, None)
# (25, 443, 'Machine 1', 'Started', 'Part 16', 'Queue 1', None, None)
# (26, 454, 'Machine 1', 'Finished', 'Part 16', 'Queue 2', None, None)
# (27, 466, 'Machine 2', 'Started', 'Part 16', 'Queue 2', None, None)
# (28, 483, 'Machine 2', 'Finished', 'Part 16', 'Queue 4', None, None)
# (29, 504, 'Machine 4', 'Started', 'Part 16', 'Queue 4', None, None)
# (30, 542, 'Machine 4', 'Finished', 'Part 16', 'Queue 5', None, None)
# (31, 554, 'Machine 5', 'Started', 'Part 16', 'Queue 5', None, None)
# (32, 564, 'Machine 5', 'Finished', 'Part 16', 'Queue 1', None, None)
# (33, 574, 'Machine 1', 'Started', 'Part 17', 'Queue 1', None, None)
# (34, 585, 'Machine 1', 'Finished', 'Part 17', 'Queue 2', None, None)
# (35, 597, 'Machine 2', 'Started', 'Part 17', 'Queue 2', None, None)
# (36, 614, 'Machine 2', 'Finished', 'Part 17', 'Queue 3', None, None)
# (37, 638, 'Machine 3', 'Started', 'Part 17', 'Queue 3', None, None)
# (38, 698, 'Machine 3', 'Finished', 'Part 17', 'Queue 5', None, None)
# (39, 710, 'Machine 5', 'Started', 'Part 17', 'Queue 5', None, None)
# (40, 720, 'Machine 5', 'Finished', 'Part 17', 'Queue 1', None, None)
# ### ============ Simulation Done ============ ###
# ================ Running Analysis ================
# Number of Parts finished: 5
# Total time of Simulation: 720
# - Maximum Cycle Time: 156
# - Minimum Cycle Time: 131
# >>> Average system cycle time: 144.0 [time unit]***
# >>> System Throughput: 0.006944444444444444 [parts / time unit]

# %% [markdown]
# Running the simulation until a targeted part id finish a certain cluster

# %%
mydt.run_digital_model(targeted_part_id=2, targeted_cluster= 3)
# Out:
# ==========  Reading the Model: 5s_determ  ==========
# ===> Big Picture
# Total number of Machines: 5
# Total number of Queues: 5
#
# ===>Detailed view of Queues:
# ----------------
# Queue 1
# Arc links: [5, 1]
# Capacity: 12
# |-- Parts stored: Part 13
# Queue Lenght: 1
# ----------------
# Queue 2
# Arc links: [1, 2]
# Capacity: 10
# Queue Lenght: 0
# ----------------
# Queue 3
# Arc links: [2, 3]
# Capacity: 10
# Queue Lenght: 0
# ----------------
# Queue 4
# Arc links: [2, 4]
# Capacity: 10
# Queue Lenght: 0
# ----------------
# Queue 5
# Arc links: None
# Capacity: 20
# Queue Lenght: 0
#
# ===>Detailed view of Machines:
# ----------------
# > Machine 1
# --Queue In:--
# Queue 1
# --Queue Out:--
# Queue 2
# Machine Cluster: 1
# ----------------
# > Machine 2
# --Queue In:--
# Queue 2
# --Queue Out:--
# Queue 3
# Queue 4
(capacity= 0)
# ! Using 'alternated' policy to allocate Part 15 to Queue 1
# Time: 433 - [Terminator] xxx Part 15 terminated xxx
# Time: 433 - [Terminator] Part 16 replaced
# Time: 433 - [Conveyor towards Queue 1] GOT Part 16
# Time: 442 - [Conveyor towards Queue 1] PUT Part 16 in the Queue 1
# Time: 443 - [Machine 1] got Part 16 from Queue 1 (capacity= 0)
# ! Using 'alternated' policy to allocate Part 16 to Queue 2
# Time: 454 - [Conveyor towards Queue 2] GOT Part 16
# Time: 465 - [Conveyor towards Queue 2] PUT Part 16 in the Queue 2
# Time: 466 - [Machine 2] got Part 16 from Queue 2 (capacity= 0)
# ! Using 'alternated' policy to allocate Part 16 to Queue 4
# Time: 483 - [Conveyor towards Queue 4] GOT Part 16
# Time: 503 - [Conveyor towards Queue 4] PUT Part 16 in the Queue 4
# Time: 504 - [Machine 4] got Part 16 from Queue 4 (capacity= 0)
# ! Using 'alternated' policy to allocate Part 16 to Queue 5
# Time: 542 - [Conveyor towards Queue 5] GOT Part 16
# Time: 553 - [Conveyor towards Queue 5] PUT Part 16 in the Queue 5
# Time: 554 - [Machine 5] got Part 16 from Queue 5 (capacity= 0)
# ! Using 'alternated' policy to allocate Part 16 to Queue 1
# Time: 564 - [Terminator] xxx Part 16 terminated xxx
# Time: 564 - [Terminator] Part 17 replaced
# Time: 564 - [Conveyor towards Queue 1] GOT Part 17
# Time: 573 - [Conveyor towards Queue 1] PUT Part 17 in the Queue 1
# Time: 574 - [Machine 1] got Part 17 from Queue 1 (capacity= 0)
# ! Using 'alternated' policy to allocate Part 17 to Queue 2
# Time: 585 - [Conveyor towards Queue 2] GOT Part 17
# Time: 596 - [Conveyor towards Queue 2] PUT Part 17 in the Queue 2
# Time: 597 - [Machine 2] got Part 17 from Queue 2 (capacity= 0)
# ! Using 'alternated' policy to allocate Part 17 to Queue 3
# Time: 614 - [Conveyor towards Queue 3] GOT Part 17
# Time: 637 - [Conveyor towards Queue 3] PUT Part 17 in the Queue 3
# Time: 638 - [Machine 3] got Part 17 from Queue 3 (capacity= 0)
# ! Using 'alternated' policy to allocate Part 17 to Queue 5
# Time: 698 - [Conveyor towards Queue 5] GOT Part 17
# Time: 709 - [Conveyor towards Queue 5] PUT Part 17 in the Queue 5
# Time: 710 - [Machine 5] got Part 17 from Queue 5 (capacity= 0)
# ! Using 'alternated' policy to allocate Part 17 to Queue 1
# Time: 720 - [Terminator] xxx Part 17 terminated xxx
# Time: 720 - [Terminator] Part 18 replaced
# Time: 720 - [Conveyor towards Queue 1] GOT Part 18
# === Reading all the events from table: digital_log ===
# (1, 0, 'Machine 1', 'Started', 'Part 13', 'Queue 1', None, None)
# (2, 11, 'Machine 1', 'Finished', 'Part 13', 'Queue 2', None, None)
# (3, 23, 'Machine 2', 'Started', 'Part 13', 'Queue 2', None, None)
# (4, 40, 'Machine 2', 'Finished', 'Part 13', 'Queue 3', None, None)
# (5, 64, 'Machine 3', 'Started', 'Part 13', 'Queue 3', None, None)
# (6, 124, 'Machine 3', 'Finished', 'Part 13', 'Queue 5', None, None)
# (7, 136, 'Machine 5', 'Started', 'Part 13', 'Queue 5', None, None)
# (8, 146, 'Machine 5', 'Finished', 'Part 13', 'Queue 1', None, None)
# (9, 156, 'Machine 1', 'Started', 'Part 14', 'Queue 1', None, None)
# (10, 167, 'Machine 1', 'Finished', 'Part 14', 'Queue 2', None, None)
# (11, 179, 'Machine 2', 'Started', 'Part 14', 'Queue 2', None, None)
# (12, 196, 'Machine 2', 'Finished', 'Part 14', 'Queue 4', None, None)
# (13, 217, 'Machine 4', 'Started', 'Part 14', 'Queue 4', None, None)
# (14, 255, 'Machine 4', 'Finished', 'Part 14', 'Queue 5', None, None)
# (15, 267, 'Machine 5', 'Started', 'Part 14', 'Queue 5', None, None)
# (16, 277, 'Machine 5', 'Finished', 'Part 14', 'Queue 1', None, None)
# (17, 287, 'Machine 1', 'Started', 'Part 15', 'Queue 1', None, None)
# (18, 298, 'Machine 1', 'Finished', 'Part 15', 'Queue 2', None, None)
# (19, 310, 'Machine 2', 'Started', 'Part 15', 'Queue 2', None, None)
# (20, 327, 'Machine 2', 'Finished', 'Part 15', 'Queue 3', None, None)
# (21, 351, 'Machine 3', 'Started', 'Part 15', 'Queue 3', None, None)
# (22, 411, 'Machine 3', 'Finished', 'Part 15', 'Queue 5', None, None)
# (23, 423, 'Machine 5', 'Started', 'Part 15', 'Queue 5', None, None)
# (24, 433, 'Machine 5', 'Finished', 'Part 15', 'Queue 1', None, None)
# (25, 443, 'Machine 1', 'Started', 'Part 16', 'Queue 1', None, None)
# (26, 454, 'Machine 1', 'Finished', 'Part 16', 'Queue 2', None, None)
# (27, 466, 'Machine 2', 'Started', 'Part 16', 'Queue 2', None, None)
# (28, 483, 'Machine 2', 'Finished', 'Part 16', 'Queue 4', None, None)
# (29, 504, 'Machine 4', 'Started', 'Part 16', 'Queue 4', None, None)
# (30, 542, 'Machine 4', 'Finished', 'Part 16', 'Queue 5', None, None)
# (31, 554, 'Machine 5', 'Started', 'Part 16', 'Queue 5', None, None)
# (32, 564, 'Machine 5', 'Finished', 'Part 16', 'Queue 1', None, None)
# (33, 574, 'Machine 1', 'Started', 'Part 17', 'Queue 1', None, None)
# (34, 585, 'Machine 1', 'Finished', 'Part 17', 'Queue 2', None, None)
# (35, 597, 'Machine 2', 'Started', 'Part 17', 'Queue 2', None, None)
# (36, 614, 'Machine 2', 'Finished', 'Part 17', 'Queue 3', None, None)
# (37, 638, 'Machine 3', 'Started', 'Part 17', 'Queue 3', None, None)
# (38, 698, 'Machine 3', 'Finished', 'Part 17', 'Queue 5', None, None)
# (39, 710, 'Machine 5', 'Started', 'Part 17', 'Queue 5', None, None)
# (40, 720, 'Machine 5', 'Finished', 'Part 17', 'Queue 1', None, None)
# ### ============ Simulation Done ============ ###
# ================ Running Analysis ================
# Number of Parts finished: 5
# Total time of Simulation: 720
# - Maximum Cycle Time: 156
# - Minimum Cycle Time: 131
# >>> Average system cycle time: 144.0 [time unit]***
# >>> System Throughput: 0.006944444444444444 [parts / time unit]

# %% [markdown]
# ### Run Synchronization (based on the last point of the simulation)

# %% [markdown]
# Run a simulation until a certain point

# %%
mydt = Digital_Twin(name= "sync_copy", maxparts= 5)
mydt.run_digital_model(plot= False)
# Out:
# Deleting existing model (excepted by 'initial.json') from the relative folder path:'models/sync_copy'
# Done! Deleted 0 successfuly
# exp_database_path: databases/sync_copy/exp_database.db
# --- printing databases paths ---
# Digital Database: 'databases/sync_copy/digital_database.db'
# Real Database: 'databases/sync_copy/real_database.db'
# ID Database: 'databases/sync_copy/ID_database.db'
# IP address not provided, Broker Manager not created. Considering an offiline enviorment
# 27 March 23:06:56 |---- Digital Twin 'sync_copy' created sucessfully ----
# ==========  Reading the Model: sync_copy  ==========
# ===> Big Picture
# Total number of Machines: 5
# Total number of Queues: 5
#
# ===>Detailed view of Queues:
# ----------------
# Queue 1
# Arc links: [5, 1]
# Capacity: 12
# |-- Parts stored: Part 1
# |-- Parts stored: Part 2
# |-- Parts stored: Part 3
# |-- Parts stored: Part 4
# |-- Parts stored: Part 5
# |-- Parts stored: Part 6
# |-- Parts stored: Part 7
# |-- Parts stored: Part 8
# |-- Parts stored: Part 9
# |-- Parts stored: Part 10
# |-- Parts stored: Part 11
# |-- Parts stored: Part 12
# Queue Lenght: 12
# ----------------
# Queue 2
# Arc links: [1, 2]
# Capacity: 10
# Queue Lenght: 0
# ----------------
# Queue 3
# Arc links: [2, 3]
# Capacity: 10
# Queue Lenght: 0
# ----------------
# Queue 4
# Arc links: [2, 4]
# Capacity: 10
# Queue Lenght: 0
# ----------------
# Queue 5
# Arc links: None
# Capacity: 20
# Queue Lenght: 0
#
# ===>Detailed view of Machines:
# ----------------
# > Machine 1
# --Queue In:--
# Queue 1
# --Queue Out:--
# Queue 2
# Machine Cluster: 1
# ----------------
# > Machine 2
# --Queue In:--
# Queue 2
# --Queue Out:--
# Queue 3
# Queue 4
# Machine Cluster: 2
# Branching Machine: Branch 1 | Machine 2
# |-- Conveyor towards Queue 3
# |-- Conveyor towards Queue 4
# ----------------
# > Machine 3
# --Queue In:--
# Queue 3
# --Queue Out:--
# Queue 5
# Machine Cluster: 3
# ----------------
# > Machine 4
# --Queue In:--
# Queue 4
# --Queue Out:--
# Queue 5
# Machine Cluster: 3
# ----------------
# > Machine 5
# --Queue In:--
# Queue 5
# --Queue Out:--
# Queue 1
# Machine Cluster: 4
# ### ============ Simulation Started ============ ###
# Time: 0 - [Machine 1] got Part 1 from Queue 1 (capacity= 11)
# ! Using 'alternated' policy to allocate Part 1 to Queue 2
# Time: 11 - [Conveyor towards Queue 2] GOT Part 1
# Time: 11 - [Machine 1] got Part 2 from Queue 1 (capacity= 10)
# ! Using 'alternated' policy to allocate Part 2 to Queue 2
# Time: 22 - [Conveyor towards Queue 2] GOT Part 2
# Time: 22 - [Machine 1] got Part 3 from Queue 1 (capacity= 9)
# Time: 22 - [Conveyor towards Queue 2] PUT Part 1 in the Queue 2
# Time: 23 - [Machine 2] got Part 1 from Queue 2 (capacity= 0)
# ! Using 'alternated' policy to allocate Part 3 to Queue 2
# Time: 33 - [Conveyor towards Queue 2] GOT Part 3
# Time: 33 - [Machine 1] got Part 4 from Queue 1 (capacity= 8)
# Time: 33 - [Conveyor towards Queue 2] PUT Part 2 in the Queue 2
# ! Using 'alternated' policy to allocate Part 1 to Queue 3
# Time: 40 - [Conveyor towards Queue 3] GOT Part 1
# Time: 40 - [Machine 2] got Part 2 from Queue 2 (capacity= 0)
# ! Using 'alternated' policy to allocate Part 4 to Queue 2
# Time: 44 - [Conveyor towards Queue 2] GOT Part 4
# Time: 44 - [Machine 1] got Part 5 from Queue 1 (capacity= 7)
# Time: 44 - [Conveyor towards Queue 2] PUT Part 3 in the Queue 2
# ! Using 'alternated' policy to allocate Part 5 to Queue 2
# Time: 55 - [Conveyor towards Queue 2] GOT Part 5
# Time: 55 - [Machine 1] got Part 6 from Queue 1 (capacity= 6)
# Time: 55 - [Conveyor towards Queue 2] PUT Part 4 in the Queue 2
# ! Using 'alternated' policy to allocate Part 2 to Queue 3
# Time: 57 - [Conveyor towards Queue 3] GOT Part 2
# Time: 57 - [Machine 2] got Part 3 from Queue 2 (capacity= 1)
# Time: 63 - [Conveyor towards Queue 3] PUT Part 1 in the Queue 3
# Time: 64 - [Machine 3] got Part 1 from Queue 3 (capacity= 0)
# ! Using 'alternated' policy to allocate Part 6 to Queue 2
# Time: 66 - [Conveyor towards Queue 2] GOT Part 6
# Time: 66 - [Machine 1] got Part 7 from Queue 1 (capacity= 5)
# Time: 66 - [Conveyor towards Queue 2] PUT Part 5 in the Queue 2
# ! Using 'alternated' policy to allocate Part 3 to Queue 3
# Time: 74 - [Conveyor towards Queue 3] GOT Part 3
# Time: 74 - [Machine 2] got Part 4 from Queue 2 (capacity= 1)
# ! Using 'alternated' policy to allocate Part 7 to Queue 2
# Time: 77 - [Conveyor towards Queue 2] GOT Part 7
# Time: 77 - [Machine 1] got Part 8 from Queue 1 (capacity= 4)
# Time: 77 - [Conveyor towards Queue 2] PUT Part 6 in the Queue 2
# Time: 80 - [Conveyor towards Queue 3] PUT Part 2 in the Queue 3
# ! Using 'alternated' policy to allocate Part 8 to Queue 2
# Time: 88 - [Conveyor towards Queue 2] GOT Part 8
# Time: 88 - [Machine 1] got Part 9 from Queue 1 (capacity= 3)
# Time: 88 - [Conveyor towards Queue 2] PUT Part 7 in the Queue 2
# ! Using 'alternated' policy to allocate Part 4 to Queue 3
# Time: 91 - [Conveyor towards Queue 3] GOT Part 4
# Time: 91 - [Machine 2] got Part 5 from Queue 2 (capacity= 2)
# Time: 97 - [Conveyor towards Queue 3] PUT Part 3 in the Queue 3
# ! Using 'alternated' policy to allocate Part 9 to Queue 2
# Time: 99 - [Conveyor towards Queue 2] GOT Part 9
# Time: 99 - [Machine 1] got Part 10 from Queue 1 (capacity= 2)
# Time: 99 - [Conveyor towards Queue 2] PUT Part 8 in the Queue 2
# ! Using 'alternated' policy to allocate Part 5 to Queue 3
# Time: 108 - [Conveyor towards Queue 3] GOT Part 5
# Time: 108 - [Machine 2] got Part 6 from Queue 2 (capacity= 2)
# ! Using 'alternated' policy to allocate Part 10 to Queue 2
# Time: 110 - [Conveyor towards Queue 2] GOT Part 10
# Time: 110 - [Machine 1] got Part 11 from Queue 1 (capacity= 1)
# Time: 110 - [Conveyor towards Queue 2] PUT Part 9 in the Queue 2
# Time: 114 - [Conveyor towards Queue 3] PUT Part 4 in the Queue 3
# ! Using 'alternated' policy to allocate Part 11 to Queue 2
# Time: 121 - [Conveyor towards Queue 2] GOT Part 11
# Time: 121 - [Machine 1] got Part 12 from Queue 1 (capacity= 0)
# Time: 121 - [Conveyor towards Queue 2] PUT Part 10 in the Queue 2
# ! Using 'alternated' policy to allocate Part 1 to Queue 5
# Time: 124 - [Conveyor towards Queue 5] GOT Part 1
# Time: 124 - [Machine 3] got Part 2 from Queue 3 (capacity= 2)
# ! Using 'alternated' policy to allocate Part 6 to Queue 3
(capacity= 0)
# ! Using 'alternated' policy to allocate Part 5 to Queue 1
# Time: 386 - [Terminator] xxx Part 5 terminated xxx
# Time: 386 - [Terminator] Part 17 replaced
# Time: 386 - [Conveyor towards Queue 1] GOT Part 17
# === Reading all the events from table: digital_log ===
# (1, 0, 'Machine 1', 'Started', 'Part 1', 'Queue 1', None, None)
# (2, 11, 'Machine 1', 'Finished', 'Part 1', 'Queue 2', None, None)
# (3, 11, 'Machine 1', 'Started', 'Part 2', 'Queue 1', None, None)
# (4, 22, 'Machine 1', 'Finished', 'Part 2', 'Queue 2', None, None)
# (5, 22, 'Machine 1', 'Started', 'Part 3', 'Queue 1', None, None)
# (6, 23, 'Machine 2', 'Started', 'Part 1', 'Queue 2', None, None)
# (7, 33, 'Machine 1', 'Finished', 'Part 3', 'Queue 2', None, None)
# (8, 33, 'Machine 1', 'Started', 'Part 4', 'Queue 1', None, None)
# (9, 40, 'Machine 2', 'Finished', 'Part 1', 'Queue 3', None, None)
# (10, 40, 'Machine 2', 'Started', 'Part 2', 'Queue 2', None, None)
# (11, 44, 'Machine 1', 'Finished', 'Part 4', 'Queue 2', None, None)
# (12, 44, 'Machine 1', 'Started', 'Part 5', 'Queue 1', None, None)
# (13, 55, 'Machine 1', 'Finished', 'Part 5', 'Queue 2', None, None)
# (14, 55, 'Machine 1', 'Started', 'Part 6', 'Queue 1', None, None)
# (15, 57, 'Machine 2', 'Finished', 'Part 2', 'Queue 3', None, None)
# (16, 57, 'Machine 2', 'Started', 'Part 3', 'Queue 2', None, None)
# (17, 64, 'Machine 3', 'Started', 'Part 1', 'Queue 3', None, None)
# (18, 66, 'Machine 1', 'Finished', 'Part 6', 'Queue 2', None, None)
# (19, 66, 'Machine 1', 'Started', 'Part 7', 'Queue 1', None, None)
# (20, 74, 'Machine 2', 'Finished', 'Part 3', 'Queue 3', None, None)
# (21, 74, 'Machine 2', 'Started', 'Part 4', 'Queue 2', None, None)
# (22, 77, 'Machine 1', 'Finished', 'Part 7', 'Queue 2', None, None)
# (23, 77, 'Machine 1', 'Started', 'Part 8', 'Queue 1', None, None)
# (24, 88, 'Machine 1', 'Finished', 'Part 8', 'Queue 2', None, None)
# (25, 88, 'Machine 1', 'Started', 'Part 9', 'Queue 1', None, None)
# (26, 91, 'Machine 2', 'Finished', 'Part 4', 'Queue 3', None, None)
# (27, 91, 'Machine 2', 'Started', 'Part 5', 'Queue 2', None, None)
# (28, 99, 'Machine 1', 'Finished', 'Part 9', 'Queue 2', None, None)
# (29, 99, 'Machine 1', 'Started', 'Part 10', 'Queue 1', None, None)
# (30, 108, 'Machine 2', 'Finished', 'Part 5', 'Queue 3', None, None)
# (31, 108, 'Machine 2', 'Started', 'Part 6', 'Queue 2', None, None)
# (32, 110, 'Machine 1', 'Finished', 'Part 10', 'Queue 2', None, None)
# (33, 110, 'Machine 1', 'Started', 'Part 11', 'Queue 1', None, None)
# (34, 121, 'Machine 1', 'Finished', 'Part 11', 'Queue 2', None, None)
# (35, 121, 'Machine 1', 'Started', 'Part 12', 'Queue 1', None, None)
# (36, 124, 'Machine 3', 'Finished', 'Part 1', 'Queue 5', None, None)
# (37, 124, 'Machine 3', 'Started', 'Part 2', 'Queue 3', None, None)
# (38, 125, 'Machine 2', 'Finished', 'Part 6', 'Queue 3', None, None)
# (39, 125, 'Machine 2', 'Started', 'Part 7', 'Queue 2', None, None)
# (40, 132, 'Machine 1', 'Finished', 'Part 12', 'Queue 2', None, None)
# (41, 136, 'Machine 5', 'Started', 'Part 1', 'Queue 5', None, None)
# (42, 142, 'Machine 2', 'Finished', 'Part 7', 'Queue 3', None, None)
# (43, 142, 'Machine 2', 'Started', 'Part 8', 'Queue 2', None, None)
# (44, 146, 'Machine 5', 'Finished', 'Part 1', 'Queue 1', None, None)
# (45, 156, 'Machine 1', 'Started', 'Part 13', 'Queue 1', None, None)
# (46, 159, 'Machine 2', 'Finished', 'Part 8', 'Queue 3', None, None)
# (47, 159, 'Machine 2', 'Started', 'Part 9', 'Queue 2', None, None)
# (48, 167, 'Machine 1', 'Finished', 'Part 13', 'Queue 2', None, None)
# (49, 176, 'Machine 2', 'Finished', 'Part 9', 'Queue 3', None, None)
# (50, 176, 'Machine 2', 'Started', 'Part 10', 'Queue 2', None, None)
# (51, 184, 'Machine 3', 'Finished', 'Part 2', 'Queue 5', None, None)
# (52, 184, 'Machine 3', 'Started', 'Part 3', 'Queue 3', None, None)
# (53, 193, 'Machine 2', 'Finished', 'Part 10', 'Queue 3', None, None)
# (54, 193, 'Machine 2', 'Started', 'Part 11', 'Queue 2', None, None)
# (55, 196, 'Machine 5', 'Started', 'Part 2', 'Queue 5', None, None)
# (56, 206, 'Machine 5', 'Finished', 'Part 2', 'Queue 1', None, None)
# (57, 210, 'Machine 2', 'Finished', 'Part 11', 'Queue 3', None, None)
# (58, 210, 'Machine 2', 'Started', 'Part 12', 'Queue 2', None, None)
# (59, 216, 'Machine 1', 'Started', 'Part 14', 'Queue 1', None, None)
# (60, 227, 'Machine 2', 'Finished', 'Part 12', 'Queue 3', None, None)
# (61, 227, 'Machine 2', 'Started', 'Part 13', 'Queue 2', None, None)
# (62, 227, 'Machine 1', 'Finished', 'Part 14', 'Queue 2', None, None)
# (63, 244, 'Machine 3', 'Finished', 'Part 3', 'Queue 5', None, None)
# (64, 244, 'Machine 3', 'Started', 'Part 4', 'Queue 3', None, None)
# (65, 244, 'Machine 2', 'Finished', 'Part 13', 'Queue 3', None, None)
# (66, 244, 'Machine 2', 'Started', 'Part 14', 'Queue 2', None, None)
# (67, 256, 'Machine 5', 'Started', 'Part 3', 'Queue 5', None, None)
# (68, 261, 'Machine 2', 'Finished', 'Part 14', 'Queue 3', None, None)
# (69, 266, 'Machine 5', 'Finished', 'Part 3', 'Queue 1', None, None)
# (70, 276, 'Machine 1', 'Started', 'Part 15', 'Queue 1', None, None)
# (71, 287, 'Machine 1', 'Finished', 'Part 15', 'Queue 2', None, None)
# (72, 299, 'Machine 2', 'Started', 'Part 15', 'Queue 2', None, None)
# (73, 304, 'Machine 3', 'Finished', 'Part 4', 'Queue 5', None, None)
# (74, 304, 'Machine 3', 'Started', 'Part 5', 'Queue 3', None, None)
# (75, 316, 'Machine 2', 'Finished', 'Part 15', 'Queue 3', None, None)
# (76, 316, 'Machine 5', 'Started', 'Part 4', 'Queue 5', None, None)
# (77, 326, 'Machine 5', 'Finished', 'Part 4', 'Queue 1', None, None)
# (78, 336, 'Machine 1', 'Started', 'Part 16', 'Queue 1', None, None)
# (79, 347, 'Machine 1', 'Finished', 'Part 16', 'Queue 2', None, None)
# (80, 359, 'Machine 2', 'Started', 'Part 16', 'Queue 2', None, None)
# (81, 364, 'Machine 3', 'Finished', 'Part 5', 'Queue 5', None, None)
# (82, 364, 'Machine 3', 'Started', 'Part 6', 'Queue 3', None, None)
# (83, 376, 'Machine 2', 'Finished', 'Part 16', 'Queue 3', None, None)
# (84, 376, 'Machine 5', 'Started', 'Part 5', 'Queue 5', None, None)
# (85, 386, 'Machine 5', 'Finished', 'Part 5', 'Queue 1', None, None)
# ### ============ Simulation Done ============ ###

# %% [markdown]
# Run Synchronization by copying the digital database created by the last simulation

# %%
mydt.run_sync(copied_realDB= True)
# Out:
#  27 March 23:07:01 |-----------------------------------------------------------------
#  27 March 23:07:01 |Big picture BEFORE Sync
#  ------------ ZONE ID: 1 ------------
# Parts in Queue: ['Part 1', 'Part 2', 'Part 3', 'Part 4', 'Part 5', 'Part 6', 'Part 7', 'Part 8', 'Part 9', 'Part 10', 'Part 11', 'Part 12']
# Part in Machine: []
#  ------------ ZONE ID: 2 ------------
# Parts in Queue: []
# Part in Machine: []
#  ------------ ZONE ID: 3 ------------
# Parts in Queue: []
# Part in Machine: []
#  ------------ ZONE ID: 4 ------------
# Parts in Queue: []
# Part in Machine: []
#  ------------ ZONE ID: 5 ------------
# Parts in Queue: []
# Part in Machine: []
#  27 March 23:07:01 |-----------------------------------------------------------------
# --------- Step by Step Sync ---------
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 mydt.run_sync(copied_realDB= True)
#
# File c:\Users\pedro\Github_repos\Digital_Twin\Digital Twin\dtwinpylib\dtwinpy\Digital_Twin.py:477, in run_sync(self, repositioning, start_time, end_time, copied_realDB)
#     462 """[OLD] Now we do this when creating the digital twin
#     463 if self.copied_realDB == True:
#     464
#    (...)
#     473     shutil.copy2(self.database_path, self.real_database_path)
#     474 """
#     476 #--- Create the synchronizer
# --> 477 synchronizer = Synchronizer(digital_model= self.digital_model, real_database_path= self.real_database_path, start_time= start_time, end_time= end_time, copied_realDB= self.copied_realDB, generate_digital_model= self.generate_digital_model, delta_t_treshold= self.delta_t_treshold)
#     479 #--- Run the synchronizer (positioning)
#     480 (machine_status, queue_status)= synchronizer.run(repositioning= repositioning)
#
# File c:\Users\pedro\Github_repos\Digital_Twin\Digital Twin\dtwinpylib\dtwinpy\synchronizer.py:715, in Synchronizer.run(self, repositioning)
#     712 self.create_zones()
#     714 #--- Find the Positioning for the parts in the real log
# --> 715 self.positioning_discovery()
#     717 #--- Run the Trace Driven Simulation
#     718 #self.sync_TDS()
#     719
#    (...)
#     722
#     723 #--- Aligment (re-positioning)
#     724 if repositioning == True:
#     725     #--- Change the positioning of the parts in the json model
#
# File c:\Users\pedro\Github_repos\Digital_Twin\Digital Twin\dtwinpylib\dtwinpy\synchronizer.py:448, in Synchronizer.positioning_discovery(self)
#     444         sys.exit()
#     447 #--- Assign Tnow according the last event of the real log
# --> 448 self.Tnow = self.full_database[-1][0]
#     450 #--- Big picture after calculations
#     451 self.helper.printer("-----------------------------------------------------------------", 'brown')
#
# IndexError: list index out of range
