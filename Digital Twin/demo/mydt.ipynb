# %% [markdown]
# ## Digital Twin Shor Demo 0.0.3.9

# %% [markdown]
# ### How to install the library?
#
# Take the path of the folder named 'dtwinpy-0.0.3.7-py3-none-any.whl' and use pip:
#
# ```
# python -m pip install "C:\Users\pedro\Github_repos\Digital_Twin\Digital Twin\dtwinpylib\dist\dtwinpy-0.0.3.9-py3-none-any.whl"
# ```
#
# or just use pip:
# ```
# python -m pip install dtwinpy==0.0.3.9
# ```

# %% [markdown]
# ### Important News:
# - Now you need to put your model json inside of a folder 'models' in the root and within that folder, inside of another folder named as your Digital Twin (models/my_dt_name/).
# - Your model need to have name as 'initial.json'. So in the end you have: ('models/mydt_name/initial.json')
# - The machine 2 is now the branching machine

# %% [markdown]
# ## My first DT

# %% [markdown]
# Importing the library

# %%
from dtwinpy.Digital_Twin import Digital_Twin
# Out:
# Model imported...
# Validator imported...
# Database imported...
# Synchronizer imported...
# Service_Handler imported...
# Broker_Manager imported...
# Helper imported...
# interfaceAPI imported...
# Updator imported...
# 'dtwinpy' version being used: 0.0.3.9

# %% [markdown]
# Create your first DT

# %%
mydt = Digital_Twin(name= '5s_determ')
# Out:
# Deleting existing model (excepted by 'initial.json') from the relative folder path:'models/5s_determ'
# Done! Deleted 0 successfuly
# exp_database_path: databases/5s_determ/exp_database.db
# --- printing databases paths ---
# Digital Database: 'databases/5s_determ/digital_database.db'
# Real Database: 'databases/5s_determ/real_database.db'
# ID Database: 'databases/5s_determ/ID_database.db'
# IP address not provided, Broker Manager not created. Considering an offiline enviorment
# 28 March 01:48:14 |---- Digital Twin '5s_determ' created sucessfully ----

# %% [markdown]
# ### Simple Simulations

# %% [markdown]
# Running a simple simulation to finish 5 parts

# %%
mydt.run_digital_model(maxparts=5, plot= False)
# Out:
# ==========  Reading the Model: 5s_determ  ==========
# ===> Big Picture
# Total number of Machines: 5
# Total number of Queues: 5
#
# ===>Detailed view of Queues:
# ----------------
# Queue 1
# Arc links: [5, 1]
# Capacity: 12
# |-- Parts stored: Part 1
# |-- Parts stored: Part 2
# |-- Parts stored: Part 3
# |-- Parts stored: Part 4
# |-- Parts stored: Part 5
# |-- Parts stored: Part 6
# |-- Parts stored: Part 7
# |-- Parts stored: Part 8
# |-- Parts stored: Part 9
# |-- Parts stored: Part 10
# |-- Parts stored: Part 11
# |-- Parts stored: Part 12
# Queue Lenght: 12
# ----------------
# Queue 2
# Arc links: [1, 2]
# Capacity: 10
# Queue Lenght: 0
# ----------------
# Queue 3
# Arc links: [2, 3]
# Capacity: 10
# Queue Lenght: 0
# ----------------
# Queue 4
# Arc links: [2, 4]
# Capacity: 10
# Queue Lenght: 0
# ----------------
# Queue 5
# Arc links: None
# Capacity: 20
# Queue Lenght: 0
#
# ===>Detailed view of Machines:
# ----------------
# > Machine 1
# --Queue In:--
# Queue 1
# ...

# %% [markdown]
# Running for a targeted part id to finish the simulation

# %%
mydt.run_digital_model(targeted_part_id= 2)
# Out:
# ==========  Reading the Model: 5s_determ  ==========
# ===> Big Picture
# Total number of Machines: 5
# Total number of Queues: 5
#
# ===>Detailed view of Queues:
# ----------------
# Queue 1
# Arc links: [5, 1]
# Capacity: 12
# |-- Parts stored: Part 1
# |-- Parts stored: Part 2
# |-- Parts stored: Part 3
# |-- Parts stored: Part 4
# |-- Parts stored: Part 5
# |-- Parts stored: Part 6
# |-- Parts stored: Part 7
# |-- Parts stored: Part 8
# |-- Parts stored: Part 9
# |-- Parts stored: Part 10
# |-- Parts stored: Part 11
# |-- Parts stored: Part 12
# Queue Lenght: 12
# ----------------
# Queue 2
# Arc links: [1, 2]
# Capacity: 10
# Queue Lenght: 0
# ----------------
# Queue 3
# Arc links: [2, 3]
# Capacity: 10
# Queue Lenght: 0
# ----------------
# Queue 4
# Arc links: [2, 4]
# Capacity: 10
# Queue Lenght: 0
# ----------------
# Queue 5
# Arc links: None
# Capacity: 20
# Queue Lenght: 0
#
# ===>Detailed view of Machines:
# ----------------
# > Machine 1
# --Queue In:--
# Queue 1
# ...

# %% [markdown]
# Running the simulation until a targeted part id finish a certain cluster

# %%
mydt.run_digital_model(targeted_part_id=2, targeted_cluster= 3)
# Out:
# ==========  Reading the Model: 5s_determ  ==========
# ===> Big Picture
# Total number of Machines: 5
# Total number of Queues: 5
#
# ===>Detailed view of Queues:
# ----------------
# Queue 1
# Arc links: [5, 1]
# Capacity: 12
# |-- Parts stored: Part 1
# |-- Parts stored: Part 2
# |-- Parts stored: Part 3
# |-- Parts stored: Part 4
# |-- Parts stored: Part 5
# |-- Parts stored: Part 6
# |-- Parts stored: Part 7
# |-- Parts stored: Part 8
# |-- Parts stored: Part 9
# |-- Parts stored: Part 10
# |-- Parts stored: Part 11
# |-- Parts stored: Part 12
# Queue Lenght: 12
# ----------------
# Queue 2
# Arc links: [1, 2]
# Capacity: 10
# Queue Lenght: 0
# ----------------
# Queue 3
# Arc links: [2, 3]
# Capacity: 10
# Queue Lenght: 0
# ----------------
# Queue 4
# Arc links: [2, 4]
# Capacity: 10
# Queue Lenght: 0
# ----------------
# Queue 5
# Arc links: None
# Capacity: 20
# Queue Lenght: 0
#
# ===>Detailed view of Machines:
# ----------------
# > Machine 1
# --Queue In:--
# Queue 1
# ...

# %% [markdown]
# ### Run Synchronization (based on the last point of the simulation)

# %% [markdown]
# Run a simulation until a certain point

# %%
mydt = Digital_Twin(name= "5s_determ", maxparts= 5)
# Out:
# Deleting existing model (excepted by 'initial.json') from the relative folder path:'models/5s_determ'
# Done! Deleted 0 successfuly
# exp_database_path: databases/5s_determ/exp_database.db
# --- printing databases paths ---
# Digital Database: 'databases/5s_determ/digital_database.db'
# Real Database: 'databases/5s_determ/real_database.db'
# ID Database: 'databases/5s_determ/ID_database.db'
# IP address not provided, Broker Manager not created. Considering an offiline enviorment
# 28 March 01:52:10 |---- Digital Twin '5s_determ' created sucessfully ----

# %%
mydt.run_digital_model(
    targeted_part_id= 2, 
    targeted_cluster= 3, 
    plot= False
)
# Out:
# ==========  Reading the Model: 5s_determ  ==========
# ===> Big Picture
# Total number of Machines: 5
# Total number of Queues: 5
#
# ===>Detailed view of Queues:
# ----------------
# Queue 1
# Arc links: [5, 1]
# Capacity: 12
# |-- Parts stored: Part 1
# |-- Parts stored: Part 2
# |-- Parts stored: Part 3
# |-- Parts stored: Part 4
# |-- Parts stored: Part 5
# |-- Parts stored: Part 6
# |-- Parts stored: Part 7
# |-- Parts stored: Part 8
# |-- Parts stored: Part 9
# |-- Parts stored: Part 10
# |-- Parts stored: Part 11
# |-- Parts stored: Part 12
# Queue Lenght: 12
# ----------------
# Queue 2
# Arc links: [1, 2]
# Capacity: 10
# Queue Lenght: 0
# ----------------
# Queue 3
# Arc links: [2, 3]
# Capacity: 10
# Queue Lenght: 0
# ----------------
# Queue 4
# Arc links: [2, 4]
# Capacity: 10
# Queue Lenght: 0
# ----------------
# Queue 5
# Arc links: None
# Capacity: 20
# Queue Lenght: 0
#
# ===>Detailed view of Machines:
# ----------------
# > Machine 1
# --Queue In:--
# Queue 1
# ...

# %% [markdown]
# Run Synchronization by copying the digital database created by the last simulation

# %%
mydt.run_sync(copied_realDB= True)
# Out:
#  28 March 01:52:30 |-----------------------------------------------------------------
#  28 March 01:52:30 |Big picture BEFORE Sync
#  ------------ ZONE ID: 1 ------------
# Parts in Queue: ['Part 1', 'Part 2', 'Part 3', 'Part 4', 'Part 5', 'Part 6', 'Part 7', 'Part 8', 'Part 9', 'Part 10', 'Part 11', 'Part 12']
# Part in Machine: []
#  ------------ ZONE ID: 2 ------------
# Parts in Queue: []
# Part in Machine: []
#  ------------ ZONE ID: 3 ------------
# Parts in Queue: []
# Part in Machine: []
#  ------------ ZONE ID: 4 ------------
# Parts in Queue: []
# Part in Machine: []
#  ------------ ZONE ID: 5 ------------
# Parts in Queue: []
# Part in Machine: []
#  28 March 01:52:30 |-----------------------------------------------------------------
# --------- Step by Step Sync ---------
#  28 March 01:52:30 |Event - machine_name: Machine 1, status: Started, part_id: Part 1, queue_name: Queue 1
#  ------------ ZONE ID: 1 ------------
# ...
